# %%
from pathlib import Path
import json

# %%
tacred_train_path = Path('/media/discoD/Corpora/TACRED/tacred/data/json/train.json')
tacred_dev_path = Path('/media/discoD/Corpora/TACRED/tacred/data/json/dev.json')
tacred_test_path = Path('/media/discoD/Corpora/TACRED/tacred/data/json/test.json')
conll04_train_path = Path('../data/datasets/conll04/conll04_train.json')
tacred_train_path_conll04 = Path('/media/discoD/Corpora/TACRED/tacred/data/json/train_conll04.json')
tacred_dev_path_conll04 = Path('/media/discoD/Corpora/TACRED/tacred/data/json/dev_conll04.json')
tacred_test_path_conll04 = Path('/media/discoD/Corpora/TACRED/tacred/data/json/test_conll04.json')

# %%
def read_json(input_file):
    with open(input_file, "r", encoding='utf-8') as reader:
        data = json.load(reader)
    return data

def save_json(json_path, examples):
    with open(json_path, 'w') as outfile:
        json.dump(examples, outfile)

def convert_token(token):
    """ Convert PTB tokens to normal tokens """
    if (token.lower() == '-lrb-'):
        return '('
    elif (token.lower() == '-rrb-'):
        return ')'
    elif (token.lower() == '-lsb-'):
        return '['
    elif (token.lower() == '-rsb-'):
        return ']'
    elif (token.lower() == '-lcb-'):
        return '{'
    elif (token.lower() == '-rcb-'):
        return '}'
    return token
        
def convert_tacred_to_conll04(tacred_example):
    sentence = [convert_token(token) for token in tacred_example['token']]
    return {'tokens': sentence, 
            'entities': [{'type': tacred_example['subj_type'], 'start': tacred_example['subj_start'], 'end': int(tacred_example['subj_end']) + 1}, 
                         {'type': tacred_example['obj_type'], 'start': tacred_example['obj_start'], 'end': int(tacred_example['obj_end']) + 1}
                        ],
            'relations': [{'type': tacred_example['relation'], 'head': 0, 'tail': 1}],
            'orig_id': tacred_example['id']
           }

def convert_tacred_dataset_to_conll04_format(in_file_path, out_file_path):
    examples = read_json(in_file_path)
    converted_examples = []
    for example in examples:
        converted_examples.append(convert_tacred_to_conll04(example))
    save_json(out_file_path, converted_examples)

def convert_tacred_benchmark_to_conll04_format():
    convert_tacred_dataset_to_conll04_format(tacred_train_path, tacred_train_path_conll04)
    convert_tacred_dataset_to_conll04_format(tacred_dev_path, tacred_dev_path_conll04)
    convert_tacred_dataset_to_conll04_format(tacred_test_path, tacred_test_path_conll04)

# %%
convert_tacred_benchmark_to_conll04_format()

# %%
tacred_train_examples = read_json(tacred_train_path)
tacred_train_examples
# Out:
# [{'guid': '61b3a5c8c9a882dcfcd2',
#   'label': 'org:founded_by',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['Tom',
#    'Thabane',
#    'resigned',
#    'in',
#    'October',
#    'last',
#    'year',
#    'to',
#    'form',
#    'the',
#    'All',
#    'Basotho',
#    'Convention',
#    '(',
#    'ABC',
#    ')',
#    ',',
#    'crossing',
#    'the',
#    'floor',
#    'with',
#    '17',
#    'members',
#    'of',
#    'parliament',
#    ',',
#    'causing',
#    'constitutional',
#    'monarch',
#    'King',
#    'Letsie',
#    'III',
#    'to',
#    'dissolve',
#    'parliament',
#    'and',
#    'call',
#    'the',
#    'snap',
#    'election',
#    '.'],
#   'span1': [10, 12],
#   'span2': [0, 1]},
#  {'guid': '61b3a65fb9b7111c4ca4',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['In',
#    '1983',
#    ',',
#    'a',
#    'year',
#    'after',
#    'the',
#    'rally',
#    ',',
#    'Forsberg',
#    'received',
#    'the',
#    'so-called',
#    '``',
#    'genius',
#    'award',
#    "''",
#    'from',
#    'the',
#    'John',
#    'D.',
#    'and',
#    'Catherine',
#    'T.',
#    'MacArthur',
#    'Foundation',
#    '.'],
#   'span1': [9, 9],
#   'span2': [19, 20]},
#  {'guid': '61b3a65fb9aeb61c81e7',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['This',
#    'was',
#    'among',
#    'a',
#    'batch',
#    'of',
#    'paperback',
#    'Oxford',
#    'World',
#    "'s",
#    'Classics',
#    'that',
#    'I',
#    'was',
#    'given',
#    'as',
#    'a',
#    'reward',
#    'for',
#    'reading',
#    'and',
#    'commenting',
#    'on',
#    'a',
#    'manuscript',
#    'for',
#    'OUP',
#    '.'],
#   'span1': [26, 26],
#   'span2': [7, 8]},
#  {'guid': '61b3a65fb9c9956eccbc',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'NUMBER',
#   'sentence': ['The',
#    'latest',
#    'investigation',
#    'was',
#    'authorized',
#    'after',
#    'the',
#    'Supreme',
#    'Court',
#    'in',
#    '2007',
#    'found',
#    'DCC',
#    'and',
#    'its',
#    'founder',
#    ',',
#    'Jim',
#    'Flavin',
#    ',',
#    'guilty',
#    'of',
#    'selling',
#    'DCC',
#    "'s",
#    '(',
#    'EURO',
#    ')',
#    '106',
#    'million',
#    '(',
#    'then',
#    '$',
#    '130',
#    'million',
#    ')',
#    'stake',
#    'in',
#    'Fyffes',
#    'after',
#    'Flavin',
#    '--',
#    'also',
#    'a',
#    'Fyffes',
#    'director',
#    'at',
#    'the',
#    'time',
#    '--',
#    'received',
#    'inside',
#    'information',
#    'about',
#    'bad',
#    'Fyffes',
#    'news',
#    'in',
#    'the',
#    'pipeline',
#    '.'],
#   'span1': [55, 55],
#   'span2': [28, 29]},
#  {'guid': '61b3a65fb9197aba87ff',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'DATE',
#   'sentence': ['The',
#    'event',
#    'is',
#    'a',
#    'response',
#    'to',
#    'a',
#    'White',
#    'House',
#    'immigration',
#    'reform',
#    'proposal',
#    'in',
#    'March',
#    ',',
#    'said',
#    'Chung-Wha',
#    'Hong',
#    ',',
#    'executive',
#    'director',
#    'of',
#    'the',
#    'New',
#    'York',
#    'Immigration',
#    'Coalition',
#    '.'],
#   'span1': [23, 26],
#   'span2': [13, 13]},
#  {'guid': '61b3a65fb94b342e4da3',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Manning',
#    'was',
#    'prime',
#    'minister',
#    'in',
#    '1991',
#    ',',
#    'and',
#    'called',
#    'a',
#    'snap',
#    'elections',
#    'in',
#    '1995',
#    'which',
#    'he',
#    'lost',
#    'to',
#    'the',
#    'UNC',
#    'after',
#    'the',
#    'party',
#    'entered',
#    'an',
#    'electoral',
#    'arrangement',
#    'with',
#    'the',
#    'National',
#    'Alliance',
#    'for',
#    'Reconstruction',
#    '.'],
#   'span1': [19, 19],
#   'span2': [29, 32]},
#  {'guid': '61b3a65fb9062d316790',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Christine',
#    'Egerszegi-Obrist',
#    '(',
#    'l',
#    ')',
#    'and',
#    'Haddad-Adel'],
#   'span1': [6, 6],
#   'span2': [0, 1]},
#  {'guid': '61b3a65fb919cf88f14e',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Al-Hubayshi',
#    'explained',
#    'that',
#    ',',
#    'far',
#    'from',
#    'being',
#    'a',
#    'mastermind',
#    ',',
#    'Abu',
#    'Zubaydah',
#    'was',
#    'responsible',
#    'for',
#    '``',
#    'receiving',
#    'people',
#    'and',
#    'financing',
#    'the',
#    'camp',
#    ',',
#    "''",
#    'that',
#    'he',
#    'once',
#    'bought',
#    'him',
#    'travel',
#    'tickets',
#    ',',
#    'and',
#    'that',
#    'he',
#    'was',
#    'the',
#    'man',
#    'he',
#    'went',
#    'to',
#    'when',
#    'he',
#    'needed',
#    'a',
#    'replacement',
#    'passport',
#    '.'],
#   'span1': [42, 42],
#   'span2': [25, 25]},
#  {'guid': '61b3a89f60d0777c9f0f',
#   'label': 'per:employee_of',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Olivia',
#    'Palermo',
#    'was',
#    'looking',
#    'very',
#    'Blair',
#    'Waldorfish',
#    'at',
#    'last',
#    'week',
#    "'s",
#    'You',
#    'Know',
#    'You',
#    'Want',
#    'It',
#    ':',
#    'Style-Inspiration-Confidence',
#    'book',
#    'launch',
#    ',',
#    'so',
#    'it',
#    "'s",
#    'only',
#    'fitting',
#    'she',
#    'ran',
#    'into',
#    'real-life',
#    'Gossip',
#    'Girl',
#    's',
#    'Leighton',
#    'Meester',
#    'and',
#    'Nicole',
#    'Fiscella',
#    'on',
#    'her',
#    'way',
#    'there',
#    '!'],
#   'span1': [0, 1],
#   'span2': [30, 31]},
#  {'guid': '61b3aa9e363a44f45c48',
#   'label': 'org:alternate_names',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['But',
#    'US',
#    'and',
#    'Indian',
#    'experts',
#    'say',
#    'it',
#    'has',
#    'hesitated',
#    'to',
#    'take',
#    'action',
#    'against',
#    'Lashkar-e-Taiba',
#    ',',
#    'which',
#    'means',
#    '``',
#    'The',
#    'Army',
#    'of',
#    'the',
#    'Pure',
#    ',',
#    "''",
#    'believing',
#    'that',
#    'the',
#    'Islamic',
#    'militants',
#    'could',
#    'prove',
#    'useful',
#    'in',
#    'pressuring',
#    'its',
#    'historic',
#    'rival',
#    'India',
#    '.'],
#   'span1': [13, 13],
#   'span2': [19, 22]},
#  {'guid': '61b3a65fb92c8c9d3d94',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NATIONALITY',
#   'sentence': ['``',
#    'I',
#    'have',
#    "n't",
#    'the',
#    'slightest',
#    'doubt',
#    'that',
#    'as',
#    'soon',
#    'as',
#    'US',
#    'and',
#    'Israeli',
#    'warships',
#    'are',
#    'in',
#    'place',
#    '...',
#    'and',
#    'attempt',
#    'to',
#    'inspect',
#    'the',
#    'first',
#    '(',
#    'Iranian',
#    ')',
#    'merchant',
#    'ship',
#    ',',
#    'a',
#    'shower',
#    'of',
#    'projectiles',
#    'will',
#    'be',
#    'unleashed',
#    '...',
#    'That',
#    'will',
#    'be',
#    'the',
#    'exact',
#    'moment',
#    'the',
#    'terrible',
#    'war',
#    'will',
#    'start',
#    ',',
#    "''",
#    'Castro',
#    'wrote',
#    'in',
#    'the',
#    'Cubadebate',
#    'website',
#    '.'],
#   'span1': [52, 52],
#   'span2': [26, 26]},
#  {'guid': '61b3a65fb97b15e6512b',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'LOCATION',
#   'sentence': ['In',
#    "O'Brien",
#    "'s",
#    'home',
#    'just',
#    'off',
#    'Broadway',
#    'in',
#    'Saratoga',
#    'Springs',
#    ',',
#    'there',
#    'are',
#    'shelves',
#    'of',
#    'books',
#    'that',
#    'mention',
#    'his',
#    'association',
#    'with',
#    'Balanchine',
#    'as',
#    'well',
#    'as',
#    'Jerome',
#    'Robbins',
#    ',',
#    'Anthony',
#    'Tudor',
#    ',',
#    'Rudolf',
#    'Nureyev',
#    'and',
#    'Mikhail',
#    'Baryshnikov',
#    ',',
#    'among',
#    'others',
#    '.'],
#   'span1': [25, 26],
#   'span2': [6, 6]},
#  {'guid': '61b3a65fb912289c20ad',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['Folded',
#    'into',
#    'Dillinger',
#    "'s",
#    'office',
#    ',',
#    'the',
#    'program',
#    'is',
#    'headed',
#    'by',
#    'director',
#    'Duncan',
#    'McCormack',
#    ',',
#    'a',
#    '51-year-old',
#    'with',
#    'a',
#    'diverse',
#    'background',
#    'that',
#    'includes',
#    'mental',
#    'health',
#    'counseling',
#    '.'],
#   'span1': [2, 2],
#   'span2': [11, 11]},
#  {'guid': '61b3a65fb9d5d39c51ce',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['So',
#    'let',
#    'me',
#    'get',
#    'this',
#    'straight',
#    '-',
#    'Murat',
#    'Kurnaz',
#    'should',
#    'have',
#    'been',
#    'shot',
#    'in',
#    '2001',
#    'because',
#    'I',
#    'asked',
#    'you',
#    'if',
#    'he',
#    'should',
#    'be',
#    'shot',
#    'for',
#    'being',
#    'German',
#    'in',
#    '2009',
#    '?'],
#   'span1': [20, 20],
#   'span2': [14, 14]},
#  {'guid': '61b3a0af8f529cfaab32',
#   'label': 'per:cities_of_residence',
#   'ner1': 'PERSON',
#   'ner2': 'CITY',
#   'sentence': ['Spencer', 'Pratt', ':', 'Beverly', 'Hills', 'Birthday', 'Boy'],
#   'span1': [0, 1],
#   'span2': [3, 4]},
#  {'guid': '61b3a65fb9d234f9bf31',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'MISC',
#   'sentence': ['While',
#    'the',
#    'Massachusetts',
#    'House',
#    'of',
#    'Representatives',
#    'debates',
#    'the',
#    'Global',
#    'Warming',
#    'Solutions',
#    'Act',
#    ',',
#    'please',
#    'show',
#    'that',
#    'commitment',
#    ',',
#    'by',
#    'publicly',
#    'calling',
#    'for',
#    'strong',
#    'near',
#    '-',
#    'and',
#    'long-term',
#    'reductions',
#    'in',
#    'global',
#    'warming',
#    'pollution',
#    'covering',
#    'all',
#    'areas',
#    'including',
#    'utilities',
#    ',',
#    'transportation',
#    ',',
#    'and',
#    'more',
#    '.'],
#   'span1': [2, 5],
#   'span2': [8, 11]},
#  {'guid': '61b3a9d0d12e113c74d9',
#   'label': 'per:children',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Besides',
#    'his',
#    'son',
#    'Charles',
#    ',',
#    'an',
#    'author',
#    'and',
#    'journalist',
#    ',',
#    'Kaiser',
#    'is',
#    'survived',
#    'by',
#    'his',
#    'wife',
#    'of',
#    '67',
#    'years',
#    ',',
#    'Hannah',
#    'Greeley',
#    'Kaiser',
#    ';',
#    'two',
#    'other',
#    'sons',
#    ',',
#    'Robert',
#    'G',
#    ',',
#    'a',
#    'former',
#    'managing',
#    'editor',
#    'and',
#    'now',
#    'an',
#    'associate',
#    'editor',
#    'of',
#    'The',
#    'Washington',
#    'Post',
#    ',',
#    'and',
#    'David',
#    ',',
#    'a',
#    'professor',
#    'of',
#    'history',
#    'at',
#    'the',
#    'Naval',
#    'War',
#    'College',
#    'in',
#    'Newport',
#    ',',
#    'RI',
#    ';',
#    'and',
#    'four',
#    'grandchildren',
#    '.'],
#   'span1': [10, 10],
#   'span2': [28, 29]},
#  {'guid': '61b3a65fb994a6170efd',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'DATE',
#   'sentence': ['It',
#    'says',
#    'that',
#    'in',
#    '2005',
#    'Sohail',
#    '``',
#    'was',
#    'visited',
#    'by',
#    'a',
#    'Jackson',
#    'Hewitt',
#    'Tax',
#    'Services',
#    'Inc.',
#    'employee',
#    ',',
#    'who',
#    'informed',
#    'Sohail',
#    'that',
#    'Santa',
#    'Barbara',
#    'Bank',
#    'had',
#    'told',
#    'Jackson',
#    'Hewitt',
#    'corporate',
#    'headquarters',
#    'that',
#    'Sohail',
#    "'s",
#    'Smart',
#    'Tax/Jackson',
#    'Hewitt',
#    'stores',
#    'were',
#    'filing',
#    'too',
#    'many',
#    'fraudulent',
#    'returns',
#    '.',
#    "''"],
#   'span1': [11, 15],
#   'span2': [4, 4]},
#  {'guid': '61b3a65fb93994c6f492',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Much',
#    'to',
#    'the',
#    'delight',
#    'of',
#    'American',
#    'hip-hop',
#    'star',
#    'Pharrell',
#    'Williams',
#    ',',
#    'who',
#    'watched',
#    'the',
#    'race',
#    'alongside',
#    'Hamilton',
#    "'s",
#    'father',
#    'Anthony',
#    ',',
#    'Hamilton',
#    'opened',
#    'up',
#    'a',
#    '2.2',
#    'sec',
#    'lead',
#    'from',
#    'Alonso',
#    'after',
#    'ten',
#    'laps',
#    'with',
#    'Massa',
#    '4.5',
#    'sec',
#    'behind',
#    '.'],
#   'span1': [16, 16],
#   'span2': [26, 26]},
#  {'guid': '61b3a65fb9ebac81f0e3',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NATIONALITY',
#   'sentence': ['DAMASCUS',
#    '--',
#    'Saudi',
#    'permanent',
#    'representative',
#    'to',
#    'the',
#    'Arab',
#    'League',
#    '(',
#    'AL',
#    ')',
#    'Ahmad',
#    'Qattan',
#    'said',
#    'here',
#    'Monday',
#    'that',
#    'he',
#    'will',
#    'attend',
#    'the',
#    'upcoming',
#    'Arab',
#    'summit',
#    'on',
#    'behalf',
#    'of',
#    'his',
#    'country',
#    ',',
#    'ruling',
#    'out',
#    'the',
#    'presence',
#    'of',
#    'Saudi',
#    'King',
#    'Abdullah',
#    'or',
#    'Foreign',
#    'Minister',
#    'Prince',
#    'Saud',
#    'al-Faisal',
#    '.'],
#   'span1': [12, 13],
#   'span2': [36, 36]},
#  {'guid': '61b3a65fb935d4998f13',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['The',
#    'Super',
#    'Bowl',
#    'is',
#    'getting',
#    ',',
#    'in',
#    'addition',
#    'to',
#    'some',
#    'Saints',
#    ',',
#    'a',
#    'controversial',
#    'dose',
#    'of',
#    'the',
#    'culture',
#    'wars',
#    ':',
#    'Florida',
#    'quarterback',
#    'prodigy',
#    'Tim',
#    'Tebow',
#    'will',
#    'appear',
#    'in',
#    'a',
#    '30-second',
#    'ad',
#    'purchased',
#    'by',
#    'the',
#    'conservative',
#    'group',
#    'Focus',
#    'on',
#    'the',
#    'Family',
#    'that',
#    'is',
#    'scheduled',
#    'to',
#    'air',
#    'during',
#    'the',
#    'nation',
#    "'s",
#    'biggest',
#    'football',
#    'game',
#    'on',
#    'Feb.',
#    '7',
#    'on',
#    'CBS',
#    '.'],
#   'span1': [36, 39],
#   'span2': [56, 56]},
#  {'guid': '61b3a65fb97b41e3c59d',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'COUNTRY',
#   'sentence': ['The',
#    'two',
#    'Bush',
#    'administrations',
#    'snubbed',
#    'highly',
#    'qualified',
#    'Northwest',
#    'Republicans',
#    '--',
#    'Dan',
#    'Evans',
#    ',',
#    'Jennifer',
#    'Dunn',
#    'and',
#    'Slade',
#    'Gorton',
#    '--',
#    'and',
#    'were',
#    'satisfied',
#    'with',
#    'making',
#    'prominent',
#    'GOP',
#    'donors',
#    'into',
#    'U.S.',
#    'ambassadors',
#    'to',
#    'diplomatic',
#    'backwaters',
#    '.'],
#   'span1': [13, 14],
#   'span2': [28, 28]},
#  {'guid': '61b3a9d0d1a18d8b6d76',
#   'label': 'per:children',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['*',
#    'Britney',
#    'Spears',
#    "'",
#    'Sunday',
#    'with',
#    'her',
#    'kids',
#    '*',
#    'Sunday',
#    'was',
#    'Britney',
#    "'s",
#    'day',
#    'with',
#    'Sean',
#    ',',
#    '2',
#    ',',
#    'and',
#    'Jayden',
#    ',',
#    '1',
#    ',',
#    'and',
#    'she',
#    'took',
#    'them',
#    'to',
#    'lunch',
#    'at',
#    'Taverna',
#    'Tony',
#    "'s",
#    'in',
#    'Malibu',
#    ',',
#    'a',
#    'Greek',
#    'restaurant',
#    '.'],
#   'span1': [11, 11],
#   'span2': [20, 20]},
#  {'guid': '61b3a89f60cb83f37693',
#   'label': 'per:employee_of',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Donald',
#    'Wildmon',
#    ',',
#    'the',
#    'founder',
#    'and',
#    'head',
#    'of',
#    'the',
#    'American',
#    'Family',
#    'Association',
#    ',',
#    'is',
#    'asking',
#    'its',
#    'members',
#    'to',
#    'petition',
#    'Congress',
#    'to',
#    'end',
#    'all',
#    'funding',
#    'for',
#    'PBS',
#    '.'],
#   'span1': [0, 1],
#   'span2': [9, 11]},
#  {'guid': '61b3a65fb96dba31ff1d',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'MISC',
#   'sentence': ['But',
#    ',',
#    'as',
#    'a',
#    'Zionist',
#    ',',
#    'he',
#    'insisted',
#    'that',
#    'the',
#    'city',
#    'remain',
#    'under',
#    'Israeli',
#    'sovereignty',
#    ',',
#    'rejecting',
#    'Palestinians',
#    "'",
#    'demand',
#    'to',
#    'make',
#    'its',
#    'Arab',
#    'part',
#    'the',
#    'capital',
#    'of',
#    'their',
#    'would-be',
#    'state',
#    '.'],
#   'span1': [6, 6],
#   'span2': [23, 23]},
#  {'guid': '61b3a65fb9b1a778e296',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Other',
#    'album',
#    'contributors',
#    'include',
#    'Lucas',
#    'Secon',
#    '(',
#    'Paula',
#    'DeAnda',
#    ',',
#    'Jordyn',
#    'Taylor',
#    ')',
#    ',',
#    'Victoria',
#    '``',
#    'Lady',
#    'V',
#    "''",
#    'Horn',
#    '(',
#    'Brandy',
#    'Norwood',
#    ',',
#    'Christina',
#    'Milian',
#    ')',
#    ',',
#    'Toby',
#    'Gad',
#    '(',
#    'Esmee',
#    'Denters',
#    ',',
#    'Pixie',
#    'Lott',
#    ')',
#    ',',
#    'Andrea',
#    'Martin',
#    '(',
#    'Tracie',
#    'Spencer',
#    ',',
#    'Melanie',
#    'Fiona',
#    ')',
#    ',',
#    'Lindy',
#    'Robbins',
#    '(',
#    'Nicole',
#    'Scherzinger',
#    ',',
#    'Ashley',
#    'Parker',
#    'Angel',
#    ')',
#    'and',
#    'Tawanna',
#    '``',
#    'Frankie',
#    'Storm',
#    "''",
#    'Dabney',
#    '(',
#    'Raven',
#    'Symone',
#    ',',
#    'Jessica',
#    'Mauboy',
#    ')',
#    '.'],
#   'span1': [44, 45],
#   'span2': [69, 70]},
#  {'guid': '61b3a65fb9149334e732',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['This',
#    'Friday',
#    '(',
#    'September',
#    '11th',
#    ')',
#    ',',
#    'Frankie',
#    'Delgado',
#    'from',
#    'The',
#    'Hills',
#    ',',
#    'Zack',
#    'Taylor',
#    ',',
#    'and',
#    'another',
#    'very',
#    'special',
#    'guest',
#    'will',
#    'be',
#    'partying',
#    'at',
#    'Club',
#    'Se7en',
#    'in',
#    'Niagara',
#    'Falls',
#    ',',
#    'Ontario',
#    '!!'],
#   'span1': [7, 8],
#   'span2': [3, 4]},
#  {'guid': '61b3a65fb92708602e74',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'CRIMINAL_CHARGE',
#   'sentence': ['Labels',
#    ':',
#    '``',
#    'celibacy',
#    "''",
#    ',',
#    'Brandon',
#    'McInerney',
#    ',',
#    'California',
#    ',',
#    'gay',
#    'youth',
#    ',',
#    'hate',
#    'crimes',
#    ',',
#    'Lawrence',
#    'King',
#    ',',
#    'murder',
#    ',',
#    'transgender',
#    'issues'],
#   'span1': [6, 7],
#   'span2': [14, 15]},
#  {'guid': '61b3a65fb9619d933e75',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['In',
#    'a',
#    'statement',
#    ',',
#    'the',
#    'Ontario',
#    'Human',
#    'Rights',
#    'Commission',
#    'said',
#    'the',
#    'contents',
#    'of',
#    'press',
#    'articles',
#    'were',
#    'beyond',
#    'its',
#    'purview',
#    ',',
#    'but',
#    'added',
#    'it',
#    '``',
#    'has',
#    'serious',
#    'concerns',
#    'about',
#    'the',
#    'content',
#    'of',
#    'a',
#    'number',
#    'of',
#    'articles',
#    'concerning',
#    'Muslims',
#    "''",
#    'published',
#    'by',
#    'Maclean',
#    "'s",
#    'and',
#    'other',
#    'media',
#    'outlets',
#    'which',
#    'were',
#    '``',
#    'identified',
#    'as',
#    'contributing',
#    'to',
#    'Islamophobia',
#    'and',
#    'promoting',
#    'societal',
#    'intolerance',
#    'towards',
#    'Muslims',
#    '.',
#    "''"],
#   'span1': [5, 8],
#   'span2': [40, 40]},
#  {'guid': '61b3afb9261780b6ea9a',
#   'label': 'per:title',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['How',
#    'creator',
#    'Fuller',
#    'is',
#    'going',
#    'to',
#    'keep',
#    'things',
#    'interesting',
#    'as',
#    'Ned',
#    'revives/kills',
#    'dead',
#    'people',
#    'each',
#    'week',
#    'and',
#    'continues',
#    'to',
#    'be',
#    'unable',
#    'to',
#    'touch',
#    'Chuck',
#    'will',
#    'be',
#    'one',
#    'of',
#    'the',
#    'TV',
#    'season',
#    "'s",
#    'true',
#    'wonders',
#    '.'],
#   'span1': [2, 2],
#   'span2': [1, 1]},
#  {'guid': '61b3a65fb91c78c34173',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['far',
#    ',',
#    'three',
#    'sex',
#    'offenders',
#    '-',
#    'George',
#    'Kennedy',
#    ',',
#    'Roy',
#    'Smith',
#    ',',
#    'and',
#    'James',
#    'Easter',
#    '-',
#    'all',
#    'of',
#    'whom',
#    'were',
#    'friends',
#    'of',
#    'Jennifer',
#    'Buchanan',
#    ',',
#    'Nevaeh',
#    "'s",
#    '24-year',
#    'old',
#    'mother',
#    ',',
#    'have',
#    'been',
#    'under',
#    'police',
#    'scrutiny',
#    'and',
#    'jailed',
#    'for',
#    'non-related',
#    'crimes',
#    'while',
#    'the',
#    'investigation',
#    'continues',
#    'more',
#    'than',
#    'a',
#    'week',
#    'after',
#    '5-year',
#    'old',
#    'Nevaeh',
#    'Buchanan',
#    'went',
#    'missing'],
#   'span1': [6, 7],
#   'span2': [25, 25]},
#  {'guid': '61b3a65fb9953abc16a5',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'CITY',
#   'sentence': ['Hong',
#    'Kong',
#    'government',
#    'unhappy',
#    'with',
#    'Disneyland',
#    "'",
#    's',
#    'performance'],
#   'span1': [5, 5],
#   'span2': [0, 1]},
#  {'guid': '61b3a65fb9d8e146364d',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Palin',
#    "'s",
#    'two',
#    'months',
#    'in',
#    'the',
#    'national',
#    'media',
#    'spotlight',
#    'raised',
#    'questions',
#    'about',
#    'some',
#    'of',
#    'her',
#    'activities',
#    'as',
#    'governor',
#    '-',
#    'in',
#    'particular',
#    ',',
#    'her',
#    'charging',
#    'the',
#    'state',
#    '$',
#    '17,000',
#    'in',
#    'per',
#    'diem',
#    'payments',
#    'for',
#    'nights',
#    'she',
#    'stayed',
#    'in',
#    'her',
#    'Wasilla',
#    'home',
#    ',',
#    'and',
#    '$',
#    '21,000',
#    'for',
#    'her',
#    'children',
#    "'s",
#    'travel.No',
#    'new',
#    'policies',
#    'have',
#    'been',
#    'set',
#    'for',
#    'those',
#    'practices',
#    ',',
#    'McAllister',
#    'said',
#    'Tuesday',
#    '.'],
#   'span1': [58, 58],
#   'span2': [22, 22]},
#  {'guid': '61b3a65fb9d3a80182be',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Adding',
#    'Dow',
#    'and',
#    'P&G',
#    'gives',
#    'the',
#    '2012',
#    'London',
#    'Olympics',
#    '11',
#    'top-tier',
#    'sponsors',
#    'including',
#    'Acer',
#    ',',
#    'Atos',
#    'Origin',
#    ',',
#    'Coca-Cola',
#    ',',
#    'GE',
#    ',',
#    'McDonald',
#    "'s",
#    ',',
#    'Omega',
#    ',',
#    'Panasonic',
#    ',',
#    'Samsung',
#    'and',
#    'Visa',
#    '.'],
#   'span1': [29, 29],
#   'span2': [18, 18]},
#  {'guid': '61b3a65fb9acd07e3698',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'CITY',
#   'sentence': ['Malia',
#    'Obama',
#    ',',
#    '10',
#    ',',
#    'once',
#    'told',
#    '``',
#    'Access',
#    'Hollywood',
#    "''",
#    'that',
#    'she',
#    'was',
#    'looking',
#    'forward',
#    'to',
#    'decorating',
#    'her',
#    'room',
#    'at',
#    'the',
#    'White',
#    'House',
#    '.'],
#   'span1': [12, 12],
#   'span2': [9, 9]},
#  {'guid': '61b3a65fb90a9181c383',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Hubbard',
#    'was',
#    'a',
#    'low-profile',
#    'economic',
#    'adviser',
#    'to',
#    'the',
#    'president',
#    'whose',
#    'strength',
#    'came',
#    'from',
#    'his',
#    'closeness',
#    'to',
#    'Bush',
#    '.'],
#   'span1': [13, 13],
#   'span2': [16, 16]},
#  {'guid': '61b3a65fb98637719ca1',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['The',
#    'country',
#    'has',
#    'been',
#    'under',
#    'emergency',
#    'rule',
#    'since',
#    'January',
#    '11',
#    'last',
#    'year',
#    ',',
#    'when',
#    'polls',
#    'were',
#    'cancelled',
#    'after',
#    'months',
#    'of',
#    'violence',
#    'over',
#    'vote-rigging',
#    'allegations',
#    'made',
#    'by',
#    'the',
#    'Awami',
#    'League',
#    'against',
#    'Zia',
#    "'s",
#    'Bangladesh',
#    'Nationalist',
#    'Party',
#    '(',
#    'BNP',
#    ')',
#    '.'],
#   'span1': [27, 28],
#   'span2': [32, 34]},
#  {'guid': '61b3a65fb9112a6a5bfc',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'LOCATION',
#   'sentence': ['Kevin',
#    'Doyle',
#    'scored',
#    'twice',
#    'to',
#    'lead',
#    'Reading',
#    'to',
#    'a',
#    '6-0',
#    'mauling',
#    'of',
#    'struggling',
#    'West',
#    'Ham',
#    ';',
#    'Tottenham',
#    'drew',
#    '1-1',
#    'at',
#    'Portsmouth',
#    ';',
#    'and',
#    'Blackburn',
#    'won',
#    '3-0',
#    'at',
#    'Wigan',
#    '.'],
#   'span1': [23, 23],
#   'span2': [13, 14]},
#  {'guid': '61b3a65fb9ec7f2a5771',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'CITY',
#   'sentence': ['The',
#    'New',
#    'South',
#    'Wales',
#    'Waratahs',
#    'booked',
#    'a',
#    'prized',
#    'berth',
#    'in',
#    'the',
#    'Super',
#    '14',
#    'finals',
#    'with',
#    'an',
#    'easy',
#    '32-16',
#    'win',
#    'over',
#    'the',
#    'Wellington',
#    'Hurricanes',
#    'on',
#    'Friday',
#    'in',
#    'Sydney',
#    '.'],
#   'span1': [1, 4],
#   'span2': [26, 26]},
#  {'guid': '61b3a65fb9726b8d67d8',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['``',
#    'We',
#    'have',
#    'received',
#    'many',
#    'proposals',
#    'and',
#    'we',
#    'are',
#    'considering',
#    'them',
#    ',',
#    "''",
#    'Iran',
#    "'s",
#    'atomic',
#    'chief',
#    ',',
#    'Ali',
#    'Akbar',
#    'Salehi',
#    ',',
#    'was',
#    'quoted',
#    'as',
#    'saying',
#    'on',
#    'Saturday',
#    'in',
#    'local',
#    'media',
#    '.'],
#   'span1': [18, 20],
#   'span2': [27, 27]},
#  {'guid': '61b3a65fb9cbc6ad6459',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'DATE',
#   'sentence': ['The',
#    'Mainland',
#    'Affairs',
#    'Council',
#    '(',
#    'MAC',
#    ')',
#    'announced',
#    'Monday',
#    'that',
#    'the',
#    'government',
#    'will',
#    'cancel',
#    'the',
#    'current',
#    'quota',
#    'of',
#    '500',
#    'per',
#    'month',
#    'for',
#    'applications',
#    'by',
#    'Chinese',
#    'spouses',
#    'for',
#    'Taiwanese',
#    'ID',
#    'cards',
#    '.'],
#   'span1': [1, 3],
#   'span2': [8, 8]},
#  {'guid': '61b3a65fb9e8bd73416a',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Olivia',
#    'gets',
#    'her',
#    'hair',
#    'cut',
#    'and',
#    'coloured',
#    'at',
#    'the',
#    'award-winning',
#    'Roy',
#    'Teeluck',
#    'Salon',
#    'in',
#    'New',
#    'York',
#    ',',
#    'where',
#    'she',
#    'also',
#    'has',
#    'hair',
#    'extensions',
#    'by',
#    'expert',
#    'Andre',
#    'Davis',
#    '.'],
#   'span1': [18, 18],
#   'span2': [10, 12]},
#  {'guid': '61b3a783300ccbca1d0c',
#   'label': 'per:siblings',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['In',
#    'the',
#    'latest',
#    'Steve',
#    'McPherson',
#    'is',
#    'Gone',
#    'News',
#    ',',
#    'his',
#    'longtime',
#    'entertainment',
#    'attorney',
#    'Tom',
#    'Hoberman',
#    'has',
#    'issued',
#    'a',
#    'deliciously',
#    'vague',
#    'and',
#    'intriguing',
#    'statement',
#    ':'],
#   'span1': [3, 4],
#   'span2': [13, 14]},
#  {'guid': '61b3a65fb9f174a17e62',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'MISC',
#   'sentence': ['The',
#    'victory',
#    'of',
#    'the',
#    'Awami',
#    'National',
#    'Party',
#    ',',
#    'or',
#    'ANP',
#    ',',
#    'was',
#    'welcomed',
#    'by',
#    'Western',
#    'officials',
#    'and',
#    'Pakistanis',
#    'as',
#    'a',
#    'clear',
#    'rejection',
#    'of',
#    'the',
#    'Taliban',
#    'and',
#    'the',
#    'religious',
#    'parties',
#    'that',
#    'backed',
#    'them',
#    'here',
#    'in',
#    'North',
#    '-',
#    'West',
#    'Frontier',
#    'province',
#    '.'],
#   'span1': [9, 9],
#   'span2': [14, 14]},
#  {'guid': '61b3af097586be8f7177',
#   'label': 'per:religion',
#   'ner1': 'PERSON',
#   'ner2': 'RELIGION',
#   'sentence': ['Devout',
#    'Catholic',
#    'Miss',
#    'Boyle',
#    'has',
#    'been',
#    'at',
#    'the',
#    'centre',
#    'of',
#    'a',
#    'media',
#    'storm',
#    'since',
#    'news',
#    'emerged',
#    'of',
#    'how',
#    'she',
#    'wowed',
#    'Britain',
#    "'s",
#    'Got',
#    'Talent',
#    'judges',
#    'Simon',
#    'Cowell',
#    'and',
#    'Piers',
#    'Morgan',
#    'with',
#    'her',
#    'amazing',
#    'opera',
#    'voice',
#    '.'],
#   'span1': [3, 3],
#   'span2': [1, 1]},
#  {'guid': '61b3a65fb93e2176c834',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['``',
#    'I',
#    'do',
#    "n't",
#    'think',
#    'the',
#    'church',
#    '(',
#    'leaders',
#    ')',
#    'would',
#    'have',
#    'been',
#    'very',
#    'happy',
#    'about',
#    'it',
#    '(',
#    'the',
#    'series',
#    ')',
#    ',',
#    'but',
#    'I',
#    'never',
#    'deal',
#    'with',
#    'those',
#    'people',
#    ',',
#    "''",
#    'he',
#    'said',
#    ',',
#    'though',
#    'he',
#    'has',
#    'met',
#    'the',
#    'California-based',
#    'Miscavige',
#    'a',
#    'few',
#    'times',
#    '.'],
#   'span1': [35, 35],
#   'span2': [40, 40]},
#  {'guid': '61b3a65fb920767d9d4f',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['The',
#    'restaurant',
#    'survey',
#    'company',
#    'Zagat',
#    'has',
#    'even',
#    'teamed',
#    'up',
#    'with',
#    'the',
#    'health',
#    'benefits',
#    'company',
#    'Wellpoint',
#    'Inc.',
#    ',',
#    'parent',
#    'company',
#    'of',
#    'Anthem',
#    'Blue',
#    'Cross',
#    ',',
#    'to',
#    'provide',
#    'Blue',
#    'Cross',
#    'members',
#    'with',
#    'an',
#    'online',
#    'tool',
#    'to',
#    'evaluate',
#    'doctors',
#    '.'],
#   'span1': [4, 4],
#   'span2': [14, 15]},
#  {'guid': '61b3aeb6b09271567c6a',
#   'label': 'per:age',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['This',
#    'is',
#    'TELEVISIONISTA',
#    'Read',
#    'more',
#    'about',
#    'AMERICAN',
#    'IDOL',
#    'Kim',
#    ',',
#    'a',
#    '25-year-old',
#    'from',
#    'Saratoga',
#    ',',
#    'Calif',
#    'known',
#    'for',
#    'insisting',
#    'to',
#    'perform',
#    'barefoot',
#    ',',
#    'was',
#    'the',
#    'first',
#    'one',
#    'cut',
#    'on',
#    'Thursday',
#    'after',
#    'failing',
#    'to',
#    'impress',
#    'even',
#    'Paula',
#    'Abdul',
#    'with',
#    'his',
#    'rendition',
#    'of',
#    '``',
#    'Careless',
#    'Whisper',
#    "''",
#    'by',
#    'George',
#    'Michael',
#    '.'],
#   'span1': [8, 8],
#   'span2': [11, 11]},
#  {'guid': '61b3a65fb9a1dc0642e9',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'LOCATION',
#   'sentence': ['In',
#    'contrast',
#    'to',
#    'Bermuda',
#    ',',
#    'where',
#    'Covidien',
#    'has',
#    'just',
#    'five',
#    'employees',
#    ',',
#    'Covidien',
#    'already',
#    'has',
#    'five',
#    'factories',
#    'and',
#    'nearly',
#    '2,000',
#    'employees',
#    'in',
#    'Ireland',
#    '.'],
#   'span1': [12, 12],
#   'span2': [3, 3]},
#  {'guid': '61b3a65fb92adb5f457c',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['The',
#    'truth',
#    'is',
#    'that',
#    'Muslim',
#    'convert',
#    'and',
#    'Democrat',
#    'Andre',
#    'Carson',
#    'was',
#    'elected',
#    'to',
#    'serve',
#    'not',
#    'because',
#    'he',
#    'is',
#    'a',
#    'Muslim',
#    'but',
#    'because',
#    'the',
#    'overwhelmingly',
#    'Christian',
#    'electorate',
#    'in',
#    'Indiana',
#    'believes',
#    'he',
#    'is',
#    'the',
#    'right',
#    'person',
#    'for',
#    'the',
#    'job',
#    '.'],
#   'span1': [16, 16],
#   'span2': [8, 9]},
#  {'guid': '61b3a65fb966e0fc0c7c',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['``',
#    'I',
#    'felt',
#    'that',
#    'it',
#    'was',
#    'a',
#    'good',
#    'collaboration',
#    ',',
#    "''",
#    'said',
#    'William',
#    'Anderson',
#    ',',
#    'author',
#    'of',
#    'several',
#    'Wilder',
#    'biographies',
#    'and',
#    'related',
#    'histories',
#    'and',
#    'a',
#    'board',
#    'member',
#    'of',
#    'the',
#    'Wilder',
#    'Home',
#    'Association',
#    'that',
#    'operates',
#    'the',
#    'Mansfield',
#    'site',
#    '.'],
#   'span1': [12, 13],
#   'span2': [18, 18]},
#  {'guid': '61b3a65fb97e6ee28380',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['According',
#    'to',
#    'Dan',
#    'Abrams',
#    ',',
#    'Bill',
#    "O'Reilly",
#    ',',
#    'Sean',
#    'Hannity',
#    ',',
#    'Alan',
#    'Colmes',
#    ',',
#    'Glen',
#    'Beck',
#    ',',
#    'John',
#    'Gibson',
#    'and',
#    'others',
#    ',',
#    'they',
#    'are',
#    '.'],
#   'span1': [2, 3],
#   'span2': [14, 15]},
#  {'guid': '61b3a9d0d1685fa9a115',
#   'label': 'per:children',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['He',
#    'is',
#    'survived',
#    'by',
#    'his',
#    'wife',
#    'of',
#    '63',
#    'years',
#    ',',
#    'Josephine',
#    'Robinson',
#    'McNair',
#    ',',
#    'of',
#    'Columbia',
#    ';',
#    'a',
#    'son',
#    ',',
#    'Robert',
#    'E.',
#    'Jr.',
#    ',',
#    'of',
#    'Columbia',
#    ';',
#    'three',
#    'daughters',
#    ',',
#    'Robin',
#    'Lee',
#    'Howell',
#    'and',
#    'Corinne',
#    'Godshall',
#    ',',
#    'of',
#    'Myrtle',
#    'Beach',
#    ',',
#    'S.C.',
#    ',',
#    'and',
#    'Claudia',
#    'Crawford',
#    'McNair',
#    ',',
#    'of',
#    'Jamestown',
#    ',',
#    'S.C.',
#    ';',
#    'six',
#    'grandchildren',
#    ';',
#    'and',
#    'one',
#    'great-grandchild',
#    '.'],
#   'span1': [10, 12],
#   'span2': [30, 32]},
#  {'guid': '61b3a65fb9506e6d82c8',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DURATION',
#   'sentence': ['Though',
#    'there',
#    'had',
#    'been',
#    'speculation',
#    'about',
#    'Mr.',
#    'Cowell',
#    "'s",
#    'status',
#    'with',
#    'the',
#    'show',
#    'for',
#    'several',
#    'weeks',
#    ',',
#    'he',
#    'said',
#    'that',
#    'he',
#    'had',
#    'only',
#    'formally',
#    'reached',
#    'an',
#    'agreement',
#    'with',
#    'Fox',
#    '``',
#    'at',
#    'half-past-10',
#    '″',
#    'this',
#    'morning',
#    'to',
#    'bring',
#    'another',
#    'reality',
#    'series',
#    ',',
#    '``',
#    'The',
#    'X',
#    'Factor',
#    ',',
#    "''",
#    'to',
#    'the',
#    'network',
#    'next',
#    'year',
#    '.'],
#   'span1': [7, 7],
#   'span2': [14, 15]},
#  {'guid': '61b3a65fb9277d8a684e',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['--',
#    'Guest',
#    'high-profile',
#    'Professional',
#    'Rodeo',
#    'Cowboys',
#    'Association',
#    'athletes',
#    ',',
#    'including',
#    'defending',
#    'world',
#    'all-around',
#    'champion',
#    'Trevor',
#    'Brazile',
#    'and',
#    'seven-time',
#    'team',
#    'roping',
#    'world',
#    'champion',
#    'Clay',
#    "O'Brien",
#    'Cooper'],
#   'span1': [3, 6],
#   'span2': [22, 24]},
#  {'guid': '61b3a65fb958001b53b3',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['``',
#    'The',
#    '`',
#    'flash',
#    "'",
#    'November',
#    'eurozone',
#    'service',
#    'sector',
#    'and',
#    'manufacturing',
#    'purchasing',
#    'managers',
#    "'",
#    'surveys',
#    '(',
#    'heightens',
#    ')',
#    'concern',
#    'that',
#    'the',
#    'eurozone',
#    "'s",
#    'recession',
#    'is',
#    'deepening',
#    ',',
#    "''",
#    'he',
#    'added',
#    '.'],
#   'span1': [28, 28],
#   'span2': [5, 5]},
#  {'guid': '61b3a65fb9bb1419f614',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['More',
#    'news',
#    'now',
#    'John',
#    ',',
#    'and',
#    'now',
#    'I',
#    'am',
#    'shocked',
#    '.',
#    'Forest',
#    'wanting',
#    'loan',
#    'deals',
#    ',',
#    'heard',
#    'that',
#    'on',
#    'east',
#    'midlands',
#    'today',
#    'last',
#    'night',
#    ',',
#    'but',
#    'brining',
#    'in',
#    'George',
#    'Boyd',
#    'is',
#    'a',
#    'bit',
#    'of',
#    'a',
#    'shock',
#    '.',
#    'Why',
#    'have',
#    'you',
#    'let',
#    'him',
#    'go',
#    ',',
#    'in',
#    'my',
#    'view',
#    'he',
#    'is',
#    'one',
#    'of',
#    'your',
#    'prize',
#    'assets',
#    '.'],
#   'span1': [41, 41],
#   'span2': [2, 2]},
#  {'guid': '61b3a65fb912f6272b32',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'DATE',
#   'sentence': ['Liu',
#    'made',
#    'the',
#    'request',
#    'Thursday',
#    'after',
#    'the',
#    'SAC',
#    'gave',
#    'a',
#    'review',
#    'of',
#    'the',
#    'national',
#    'Olympic',
#    'team',
#    "'s",
#    'participation',
#    'in',
#    'the',
#    '2008',
#    'Beijing',
#    'Olympic',
#    'Games',
#    'and',
#    'the',
#    'SAC',
#    "'s",
#    'vision',
#    'for',
#    'the',
#    'future',
#    'of',
#    'sports',
#    'in',
#    'Taiwan',
#    ',',
#    'at',
#    'a',
#    'regular',
#    'Cabinet',
#    'meeting',
#    '.'],
#   'span1': [7, 7],
#   'span2': [30, 31]},
#  {'guid': '61b3aa9e368c0e366f04',
#   'label': 'org:alternate_names',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Abu',
#    'Mujahid',
#    ',',
#    'spokesman',
#    'of',
#    'the',
#    'Popular',
#    'Resistance',
#    'Committee',
#    '(',
#    'PRC',
#    ')',
#    'said',
#    'in',
#    'a',
#    'statement',
#    'sent',
#    'to',
#    'reporters',
#    'that',
#    'the',
#    'contradicted',
#    'statements',
#    'of',
#    'the',
#    'Israeli',
#    'officials',
#    '``',
#    'show',
#    'that',
#    'Israel',
#    'is',
#    'the',
#    'one',
#    'which',
#    'delays',
#    'and',
#    'blocks',
#    'the',
#    'swap',
#    '.',
#    "''"],
#   'span1': [10, 10],
#   'span2': [6, 8]},
#  {'guid': '61b3a65fb9f8d6d093f6',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['He',
#    'said',
#    'Iran',
#    'had',
#    '3,300',
#    'or',
#    '3,400',
#    'centrifuges',
#    'of',
#    'the',
#    '1970s',
#    'vintage',
#    'P-1',
#    'type',
#    'in',
#    'the',
#    'Natanz',
#    'enrichment',
#    'hall',
#    ',',
#    'up',
#    'from',
#    '3,000',
#    'at',
#    'the',
#    'end',
#    'of',
#    'last',
#    'year',
#    '.'],
#   'span1': [0, 0],
#   'span2': [6, 6]},
#  {'guid': '61b3a65fb998517072b0',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['GM',
#    'China',
#    ',',
#    'China',
#    "'",
#    's',
#    'FAW',
#    'launch',
#    'joint',
#    'venture'],
#   'span1': [6, 6],
#   'span2': [0, 1]},
#  {'guid': '61b3a89f60cae0c7f39f',
#   'label': 'per:employee_of',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['California',
#    'Sen',
#    'Boxer',
#    'seeks',
#    'support',
#    'for',
#    'Senate',
#    'climate',
#    'bill',
#    '``',
#    'There',
#    'are',
#    'some',
#    'in',
#    'the',
#    'Senate',
#    'who',
#    'insist',
#    'that',
#    'global',
#    'warming',
#    'is',
#    'nothing',
#    'more',
#    'than',
#    'science',
#    'fiction',
#    ',',
#    "''",
#    'Sen',
#    'Barbara',
#    'Boxer',
#    'said',
#    'in',
#    'the',
#    'Democrats',
#    "'",
#    'weekly',
#    'radio',
#    'address',
#    '.'],
#   'span1': [30, 31],
#   'span2': [29, 29]},
#  {'guid': '61b3a65fb94017944f68',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'LOCATION',
#   'sentence': ['Kurnaz',
#    'was',
#    'captured',
#    'in',
#    'Pakistan',
#    'by',
#    'U.S.',
#    'forces',
#    'soon',
#    'after',
#    'the',
#    'Sept.',
#    '11',
#    ',',
#    '2001',
#    'terror',
#    'attacks',
#    'in',
#    'the',
#    'United',
#    'States',
#    'and',
#    'later',
#    'imprisoned',
#    'at',
#    'Guantanamo',
#    'Bay',
#    'in',
#    '2002',
#    '.'],
#   'span1': [0, 0],
#   'span2': [25, 26]},
#  {'guid': '61b3a65fb93287603afd',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['Consummate',
#    'entertainer',
#    'Nancy',
#    'Wilson',
#    ',',
#    'composer',
#    'and',
#    'pianist',
#    'Herbie',
#    'Hancock',
#    ',',
#    'producer',
#    'Quincy',
#    'Jones',
#    ',',
#    'pianist',
#    'and',
#    'lifelong',
#    'friend',
#    'Oliver',
#    'Jones',
#    'and',
#    'soprano',
#    'Measha',
#    'Brueggergosman',
#    'will',
#    'gather',
#    'to',
#    'celebrate',
#    'the',
#    'life',
#    'and',
#    'works',
#    'of',
#    'the',
#    'jazz',
#    'legend',
#    ',',
#    'who',
#    'died',
#    'Dec.',
#    '23',
#    'from',
#    'kidney',
#    'failure',
#    'at',
#    'his',
#    'home',
#    'in',
#    'a',
#    'Toronto',
#    'suburb',
#    '.'],
#   'span1': [46, 46],
#   'span2': [40, 41]},
#  {'guid': '61b3a65fb9024b7ea5d2',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['If',
#    'the',
#    'strike',
#    'ends',
#    'soon',
#    ',',
#    'ABS',
#    'president',
#    'Steve',
#    'McPherson',
#    'has',
#    'said',
#    'he',
#    'would',
#    'prefer',
#    'to',
#    'leave',
#    'Wednesday',
#    'nights',
#    'intact',
#    'as',
#    'the',
#    'entire',
#    'line-up',
#    'of',
#    'freshman',
#    'shows',
#    'is',
#    'doing',
#    'quite',
#    'well',
#    'in',
#    'which',
#    'case',
#    'they',
#    'may',
#    'have',
#    'to',
#    'find',
#    'a',
#    'new',
#    'slot',
#    'for',
#    '``',
#    'LOST',
#    '.',
#    "''"],
#   'span1': [12, 12],
#   'span2': [8, 9]},
#  {'guid': '61b3a65fb917626fc490',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['For',
#    'most',
#    'of',
#    'her',
#    'life',
#    ',',
#    'she',
#    'had',
#    'balanced',
#    'the',
#    'challenges',
#    'of',
#    'her',
#    'private',
#    'life',
#    'with',
#    'the',
#    'joy',
#    'of',
#    'singing',
#    ',',
#    'stepping',
#    'onstage',
#    'and',
#    'transforming',
#    'herself',
#    'into',
#    'characters',
#    'that',
#    'made',
#    'her',
#    'forget',
#    'her',
#    'troubles',
#    '.'],
#   'span1': [6, 6],
#   'span2': [32, 32]},
#  {'guid': '61b3a65fb9d4ad03295c',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['The',
#    'backing',
#    'of',
#    'Paralyzed',
#    'Veterans',
#    'of',
#    'America',
#    ',',
#    'Wounded',
#    'Warrior',
#    'Project',
#    ',',
#    'and',
#    'Disabled',
#    'American',
#    'Veterans',
#    'adds',
#    'momentum',
#    'to',
#    'the',
#    'Chairman',
#    "'s",
#    'veterans',
#    "'",
#    'health',
#    'care',
#    'agenda',
#    ',',
#    'which',
#    'includes',
#    'reforming',
#    'health',
#    'care',
#    'funding',
#    ',',
#    'breaking',
#    'down',
#    'health',
#    'care',
#    'barriers',
#    'for',
#    'rural',
#    'veterans',
#    ',',
#    'and',
#    'establishing',
#    'a',
#    'permanent',
#    'support',
#    'program',
#    'for',
#    'family',
#    'caregivers',
#    '.'],
#   'span1': [3, 6],
#   'span2': [8, 10]},
#  {'guid': '61b3a65fb9186f4735b9',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['---------------------------------',
#    'A',
#    'Response',
#    'by',
#    'the',
#    'American',
#    'Psychiatric',
#    'Association',
#    ':',
#    '``',
#    'We',
#    'Advocate',
#    'For',
#    'the',
#    'Patient',
#    'and',
#    'For',
#    'Quality',
#    'Treatment',
#    "''",
#    '(',
#    'Up',
#    'to',
#    'ToC',
#    ')',
#    'James',
#    'Thompson',
#    ',',
#    'M.D.',
#    ',',
#    'is',
#    'the',
#    'deputy',
#    'medical',
#    'director',
#    'of',
#    'the',
#    'Office',
#    'of',
#    'Education',
#    'at',
#    'the',
#    'American',
#    'Psychiatric',
#    'Association',
#    '.'],
#   'span1': [5, 7],
#   'span2': [16, 18]},
#  {'guid': '61b3a65fb9a5039a3f39',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['She',
#    'said',
#    'she',
#    'wanted',
#    'to',
#    'leave',
#    'her',
#    'three',
#    'children',
#    'an',
#    'inheritance',
#    'and',
#    'take',
#    'care',
#    'of',
#    'her',
#    'sick',
#    'son',
#    '.'],
#   'span1': [6, 6],
#   'span2': [7, 7]},
#  {'guid': '61b3a65fb97fc0714bfa',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Then',
#    'I',
#    'was',
#    'contacted',
#    'in',
#    'recent',
#    'weeks',
#    'by',
#    '46-year-old',
#    'Brian',
#    'Davis',
#    ',',
#    'an',
#    'Arizona',
#    'resident',
#    ',',
#    'who',
#    'told',
#    'me',
#    'about',
#    'his',
#    'intimate',
#    'relationship',
#    'with',
#    'Mark',
#    'Buse',
#    '(',
#    'confirmed',
#    'by',
#    'his',
#    'mother',
#    ',',
#    'as',
#    'well',
#    'as',
#    'by',
#    'a',
#    'long-time',
#    'friend',
#    ')',
#    ',',
#    'and',
#    'who',
#    'decided',
#    'he',
#    'needed',
#    'to',
#    'tell',
#    'the',
#    'truth',
#    'about',
#    'Buse',
#    ',',
#    'on',
#    'the',
#    'record',
#    ',',
#    'in',
#    'light',
#    'of',
#    'John',
#    'McCain',
#    "'s",
#    'dramatic',
#    'shift',
#    'to',
#    'the',
#    'ideological',
#    'religious',
#    'right',
#    'in',
#    'this',
#    'election',
#    'and',
#    'his',
#    'choice',
#    'of',
#    'Sarah',
#    'Palin',
#    ',',
#    'starlet',
#    'of',
#    'the',
#    'evangelical',
#    'movement',
#    ',',
#    'as',
#    'a',
#    'running',
#    'mate',
#    '.'],
#   'span1': [51, 51],
#   'span2': [74, 74]},
#  {'guid': '61b3a65fb946b1a7cbbc',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['[',
#    'By',
#    'the',
#    'way',
#    ',',
#    'I',
#    'first',
#    'pointed',
#    'out',
#    'Alice',
#    'when',
#    'she',
#    'was',
#    'announced',
#    'as',
#    'being',
#    'the',
#    'new',
#    'Agent',
#    'Provocateur',
#    'face',
#    ',',
#    'since',
#    'then',
#    'they',
#    "'ve",
#    'been',
#    'giving',
#    'her',
#    'a',
#    'MASSIVE',
#    'PR',
#    'push',
#    '(',
#    'obviously',
#    'got',
#    'big',
#    'plans',
#    'for',
#    'her',
#    ')',
#    ',',
#    'in',
#    'The',
#    'Sun',
#    'in',
#    'particular',
#    ',',
#    'which',
#    'I',
#    'missed',
#    '.'],
#   'span1': [9, 9],
#   'span2': [11, 11]},
#  {'guid': '61b3a65fb9efc6fe2c42',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'MISC',
#   'sentence': ['I',
#    'had',
#    'to',
#    'split',
#    'Carnival',
#    'because',
#    'I',
#    'feel',
#    'that',
#    'there',
#    'is',
#    'a',
#    'marked',
#    'difference',
#    'in',
#    'the',
#    'Spirit',
#    'Class',
#    'ships',
#    'and',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'fleet',
#    '.'],
#   'span1': [4, 4],
#   'span2': [16, 17]},
#  {'guid': '61b3a65fb906b5a32bb9',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['Now',
#    ',',
#    'back',
#    'to',
#    'the',
#    'topic',
#    'at',
#    'hand',
#    '-',
#    'Is',
#    'it',
#    'just',
#    'me',
#    ',',
#    'or',
#    'is',
#    'that',
#    'picture',
#    'of',
#    'Alice',
#    'Dellal',
#    'that',
#    'simply',
#    'says',
#    '``',
#    'metal',
#    "''",
#    'at',
#    'the',
#    'top',
#    'similar',
#    'to',
#    'this',
#    'one',
#    'of',
#    'Madonna',
#    '?'],
#   'span1': [19, 20],
#   'span2': [33, 33]},
#  {'guid': '61b3a65fb979ba7d2dde',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'RELIGION',
#   'sentence': ['The',
#    'Ontario',
#    'Human',
#    'Rights',
#    'Commission',
#    'is',
#    'arguing',
#    'that',
#    'a',
#    'provincial',
#    'court',
#    'judge',
#    'failed',
#    'to',
#    'recognize',
#    'the',
#    'religious',
#    'freedoms',
#    'of',
#    'a',
#    'Muslim',
#    'woman',
#    'when',
#    'he',
#    'ordered',
#    'her',
#    'to',
#    'testify',
#    'at',
#    'a',
#    'sexual',
#    'assault',
#    'trial',
#    'without',
#    'a',
#    'veil',
#    'known',
#    'as',
#    'a',
#    'niqab',
#    '.'],
#   'span1': [1, 4],
#   'span2': [20, 20]},
#  {'guid': '61b3a0af8fbc91cad61a',
#   'label': 'per:cities_of_residence',
#   'ner1': 'PERSON',
#   'ner2': 'CITY',
#   'sentence': ['The',
#    'same',
#    'week',
#    'that',
#    'a',
#    'Los',
#    'Angeles',
#    'salon',
#    'owner',
#    'was',
#    'pleading',
#    'with',
#    'Britney',
#    'Spears',
#    'not',
#    'to',
#    'buzz',
#    'her',
#    'head',
#    ',',
#    'barbers',
#    'were',
#    'laying',
#    'tracks',
#    'across',
#    'the',
#    'scalps',
#    'of',
#    'all',
#    'sorts',
#    'of',
#    'men',
#    'at',
#    'the',
#    'Aidan',
#    'Gill',
#    'for',
#    'Men',
#    'salon',
#    'in',
#    'New',
#    'Orleans',
#    '.'],
#   'span1': [12, 13],
#   'span2': [5, 6]},
#  {'guid': '61b3a65fb94c5c0d09bf',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['This',
#    'movie',
#    ',',
#    'written',
#    'by',
#    'Ben',
#    'Stiller',
#    ',',
#    'Etan',
#    'Cohen',
#    ',',
#    'and',
#    'the',
#    'actor',
#    'Justin',
#    'Theroux',
#    'and',
#    'directed',
#    'by',
#    'Stiller',
#    ',',
#    'will',
#    'certainly',
#    'make',
#    'more',
#    'money',
#    ',',
#    'which',
#    'will',
#    'tickle',
#    'the',
#    'executives',
#    ',',
#    'like',
#    'Grossman',
#    ',',
#    'that',
#    '``',
#    'Tropic',
#    'Thunder',
#    "''",
#    'wants',
#    'to',
#    'send',
#    'up',
#    '.'],
#   'span1': [14, 15],
#   'span2': [8, 9]},
#  {'guid': '61b3a65fb90e9cbfbd79',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['She',
#    'was',
#    'the',
#    'daughter',
#    'of',
#    'Larkin',
#    'Douglass',
#    'Watson',
#    ',',
#    'an',
#    'actor',
#    'who',
#    'appeared',
#    'for',
#    '15',
#    'years',
#    'on',
#    'the',
#    'NBC',
#    'soap',
#    'opera',
#    '``',
#    'Another',
#    'World',
#    '.',
#    "''"],
#   'span1': [0, 0],
#   'span2': [10, 10]},
#  {'guid': '61b3afb9262361c28dd2',
#   'label': 'per:title',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['In',
#    'a',
#    'recent',
#    'speech',
#    ',',
#    'Al',
#    'Hubbard',
#    ',',
#    'chairman',
#    'of',
#    'the',
#    'National',
#    'Economic',
#    'Council',
#    ',',
#    'predicted',
#    'Bush',
#    'would',
#    'generate',
#    '``',
#    'headlines',
#    'above',
#    'the',
#    'fold',
#    'that',
#    'will',
#    'knock',
#    'your',
#    'socks',
#    'off',
#    'in',
#    'terms',
#    'of',
#    'our',
#    'commitment',
#    'to',
#    'energy',
#    'independence',
#    '.',
#    "''"],
#   'span1': [5, 6],
#   'span2': [8, 8]},
#  {'guid': '61b3aeaebf225e535f4a',
#   'label': 'org:website',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'URL',
#   'sentence': ['Barnes',
#    'Foundation',
#    ':',
#    'http://www.barnesfoundation.org/'],
#   'span1': [0, 1],
#   'span2': [3, 3]},
#  {'guid': '61b3a65fb9e7492d1fe1',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'NUMBER',
#   'sentence': ['The',
#    'broader',
#    'Topix',
#    'index',
#    'of',
#    'all',
#    'First',
#    'Section',
#    'issues',
#    'on',
#    'the',
#    'Tokyo',
#    'Stock',
#    'Exchange',
#    'added',
#    '32.52',
#    'points',
#    ',',
#    'or',
#    '2.07',
#    'percent',
#    ',',
#    'to',
#    'end',
#    'at',
#    '1,606.49',
#    '.'],
#   'span1': [11, 13],
#   'span2': [25, 25]},
#  {'guid': '61b3a65fb97f40ef033a',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'LOCATION',
#   'sentence': ["Shi'ites",
#    'believe',
#    'that',
#    'Imam',
#    'Mahdi',
#    'is',
#    'hidden',
#    'and',
#    'will',
#    'never',
#    'die',
#    ',',
#    'but',
#    'he',
#    'will',
#    'return',
#    'at',
#    'the',
#    'end',
#    'of',
#    'the',
#    'time',
#    'to',
#    'bring',
#    'peace',
#    'and',
#    'justice',
#    'to',
#    'the',
#    'mankind',
#    '.'],
#   'span1': [13, 13],
#   'span2': [29, 29]},
#  {'guid': '61b3a0af8f45eb343ec5',
#   'label': 'per:cities_of_residence',
#   'ner1': 'PERSON',
#   'ner2': 'CITY',
#   'sentence': ['Meadows',
# ...
#    'comic',
#    'stars',
#    '.'],
#   'span1': [18, 18],
#   'span2': [34, 34]},
#  {'guid': '61b3a65fb9c02e99c018',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['He',
#    'did',
#    "n't",
#    'say',
#    'give',
#    'me',
#    'liberty',
#    'later',
#    ',',
#    "''",
#    'his',
#    'sister-in-law',
#    ',',
#    'Juanita',
#    'Jackson',
#    'Mitchell',
#    ',',
#    'told',
#    'The',
#    'Post',
#    'in',
#    '1977',
#    '.'],
#   'span1': [0, 0],
#   'span2': [19, 19]},
#  {'guid': '61b3a5158d9c9a7cc1aa',
#   'label': 'org:city_of_headquarters',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'CITY',
#   'sentence': ['Acerra',
#    'was',
#    'principal',
#    'of',
#    'Nitschmann',
#    'Middle',
#    'School',
#    'in',
#    'Bethlehem',
#    'when',
#    'he',
#    'was',
#    'arrested',
#    'in',
#    'his',
#    'office',
#    'during',
#    'a',
#    'police',
#    'sting',
#    'Feb',
#    '27',
#    '.'],
#   'span1': [4, 6],
#   'span2': [8, 8]},
#  {'guid': '61b3abc3f6076672ab56',
#   'label': 'org:stateorprovince_of_headquarters',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'STATE_OR_PROVINCE',
#   'sentence': ['Speculation',
#    'about',
#    'a',
#    'potential',
#    'takeover',
#    'of',
#    'Ipsco',
#    ',',
#    'which',
#    'is',
#    'based',
#    'in',
#    'Regina',
#    ',',
#    'Saskatchewan',
#    ',',
#    'but',
#    'has',
#    'executive',
#    'offices',
#    'in',
#    'Lisle',
#    ',',
#    'Ill',
#    ',',
#    'started',
#    'over',
#    'a',
#    'month',
#    'ago',
#    '.'],
#   'span1': [6, 6],
#   'span2': [14, 14]},
#  {'guid': '61b3a65fb910011c32d9',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['Yet',
#    'last',
#    'Sunday',
#    ',',
#    'when',
#    'asked',
#    'by',
#    'David',
#    'Gregory',
#    'on',
#    '``',
#    'Meet',
#    'the',
#    'Press',
#    "''",
#    'if',
#    'he',
#    'was',
#    'troubled',
#    'by',
#    'current',
#    'threats',
#    'of',
#    '``',
#    'violence',
#    'against',
#    'the',
#    'government',
#    ',',
#    "''",
#    'Coburn',
#    'blamed',
#    'not',
#    'the',
#    'nuts',
#    'but',
#    'the',
#    'government',
#    '.'],
#   'span1': [7, 8],
#   'span2': [20, 20]},
#  {'guid': '61b3a65fb97978dd79aa',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'MISC',
#   'sentence': ['He',
#    'notes',
#    'Bhutto',
#    "'s",
#    'emotional',
#    'outburst',
#    'before',
#    'the',
#    'Security',
#    'Council',
#    'and',
#    'then',
#    'proceeds',
#    'to',
#    'inform',
#    'Nixon',
#    'of',
#    'a',
#    'long',
#    'letter',
#    'received',
#    'from',
#    'Mrs.',
#    'Gandhi',
#    ',',
#    'who',
#    'sets',
#    'out',
#    'her',
#    'points',
#    'detailing',
#    'where',
#    'the',
#    'Americans',
#    'had',
#    'gone',
#    'wrong',
#    'in',
#    'their',
#    'assessment',
#    'of',
#    'the',
#    'Bangladesh',
#    'crisis',
#    '.'],
#   'span1': [28, 28],
#   'span2': [33, 33]},
#  {'guid': '61b3a9d0d12c3c8287e0',
#   'label': 'per:children',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Besides',
#    'his',
#    'son',
#    'Charles',
#    ',',
#    'an',
#    'author',
#    'and',
#    'journalist',
#    ',',
#    'Kaiser',
#    'is',
#    'survived',
#    'by',
#    'his',
#    'wife',
#    'of',
#    '67',
#    'years',
#    ',',
#    'Hannah',
#    'Greeley',
#    'Kaiser',
#    ';',
#    'two',
#    'other',
#    'sons',
#    ',',
#    'Robert',
#    'G.',
#    ',',
#    'a',
#    'former',
#    'managing',
#    'editor',
#    'and',
#    'now',
#    'an',
#    'associate',
#    'editor',
#    'of',
#    'The',
#    'Washington',
#    'Post',
#    ',',
#    'and',
#    'David',
#    ',',
#    'a',
#    'professor',
#    'of',
#    'history',
#    'at',
#    'the',
#    'Naval',
#    'War',
#    'College',
#    'in',
#    'Newport',
#    ',',
#    'R.I.',
#    ';',
#    'and',
#    'four',
#    'grandchildren',
#    '.'],
#   'span1': [14, 14],
#   'span2': [28, 29]},
#  {'guid': '61b3a65fb9b27fffec8d',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['The',
#    '2008',
#    'Zagat',
#    'guide',
#    'to',
#    'New',
#    'York',
#    'City',
#    'lists',
#    '26',
#    'restaurants',
#    'in',
#    'the',
#    'Bronx',
#    ',',
#    'including',
#    'Le',
#    'Refuge',
#    'Inn',
#    'and',
#    'Willie',
#    "'s",
#    'Steak',
#    'House',
#    ',',
#    '1832',
#    'Westchester',
#    'Ave.',
#    ',',
#    '718-822-9697',
#    ',',
#    'which',
#    'also',
#    'serves',
#    'Latin',
#    'food',
#    'and',
#    'offers',
#    'live',
#    'music',
#    'Wednesday',
#    'and',
#    'Saturday',
#    'nights',
#    '.'],
#   'span1': [2, 2],
#   'span2': [9, 9]},
#  {'guid': '61b3a89f6081d896aab1',
#   'label': 'per:employee_of',
#   'ner1': 'PERSON',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Philip',
#    'Chen',
#    ',',
#    '51',
#    ',',
#    'will',
#    'be',
#    'appointed',
#    'chairman',
#    'of',
#    'John',
#    'Swire',
#    '&',
#    'Sons',
#    '(',
#    'China',
#    ')',
#    'Ltd.',
#    'on',
#    'July',
#    '1',
#    ',',
#    'but',
#    'he',
#    'will',
#    'remain',
#    'at',
#    'Cathay',
#    'Pacific',
#    'as',
#    'a',
#    'nonexecutive',
#    'deputy',
#    'chairman',
#    ',',
#    'Swire',
#    'said',
#    'in',
#    'a',
#    'statement',
#    'Thursday',
#    '.'],
#   'span1': [0, 1],
#   'span2': [27, 28]},
#  {'guid': '61b3a65fb94a91bd93ed',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'LOCATION',
#   'sentence': ['The',
#    'North',
#    "'s",
#    'Korean',
#    'Central',
#    'News',
#    'Agency',
#    'said',
#    'Hill',
#    'handed',
#    'what',
#    'it',
#    'described',
#    'as',
#    'a',
#    '``',
#    'personal',
#    'letter',
#    "''",
#    'from',
#    'Bush',
#    'to',
#    'North',
#    'Korean',
#    'Foreign',
#    'Minister',
#    'Pak',
#    'Ui',
#    'Chun',
#    '.'],
#   'span1': [3, 6],
#   'span2': [1, 1]},
#  {'guid': '61b3afb9260a2ed54a36',
#   'label': 'per:title',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['Hometown',
#    ':',
#    'Durban',
#    ',',
#    'South',
#    'Africa',
#    'Cool',
#    'fact',
#    ':',
#    '``',
#    'Pushing',
#    'Daisies',
#    "''",
#    'executive',
#    'producer',
#    'Bryan',
#    'Fuller',
#    '(',
#    '``',
#    'Heroes',
#    "''",
#    ')',
#    'tailor',
#    'made',
#    'the',
#    'role',
#    'of',
#    'Ned',
#    'for',
#    'Pace',
#    '.'],
#   'span1': [15, 16],
#   'span2': [13, 14]},
#  {'guid': '61b3a65fb9c68eafe7ee',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'TITLE',
#   'sentence': ['Book',
#    'and',
#    'lyrics',
#    'by',
#    'Betty',
#    'Comden',
#    'and',
#    'Adolph',
#    'Green',
#    ';',
#    'music',
#    'by',
#    'Jule',
#    'Styne',
#    ';',
#    'directed',
#    'and',
#    'choreographed',
#    'by',
#    'Kathleen',
#    'Marshall',
#    ';',
#    'original',
#    'production',
#    'directed',
#    'by',
#    'Jerome',
#    'Robbins',
#    ',',
#    'dance',
#    'and',
#    'musical',
#    'numbers',
#    'staged',
#    'by',
#    'Robbins',
#    'and',
#    'Bob',
#    'Fosse',
#    ';',
#    'music',
#    'director',
#    ',',
#    'Rob',
#    'Berman',
#    ';',
#    'sets',
#    'by',
#    'John',
#    'Lee',
#    'Beatty',
#    ';',
#    'costumes',
#    'by',
#    'Martin',
#    'Pakledinaz',
#    ';',
#    'lighting',
#    'by',
#    'Peter',
#    'Kaczorowski',
#    ';',
#    'sound',
#    'by',
#    'Scott',
#    'Lehrer',
#    ';',
#    'concert',
#    'adaptation',
#    'by',
#    'David',
#    'Ives',
#    ';',
#    'music',
#    'coordinator',
#    ',',
#    'Seymour',
#    'Red',
#    'Press',
#    ';',
#    'original',
#    'orchestrations',
#    'by',
#    'Robert',
#    'Russell',
#    'Bennett',
#    ';',
#    'associate',
#    'choreographer',
#    ',',
#    'Rommy',
#    'Sandhu',
#    '.'],
#   'span1': [35, 35],
#   'span2': [88, 88]},
#  {'guid': '61b3a65fb9ceb35df6d2',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['On',
#    'Sunday',
#    ',',
#    'the',
#    'ranking',
#    'Republican',
#    'on',
#    'the',
#    'Judiciary',
#    'Committee',
#    ',',
#    'Arlen',
#    'Specter',
#    'of',
#    'Pennsylvania',
#    ',',
#    'called',
#    'Gonzales',
#    "'",
#    'testimony',
#    '``',
#    'very',
#    ',',
#    'very',
#    'damaging',
#    'to',
#    'his',
#    'own',
#    'credibility',
#    '.',
#    "''"],
#   'span1': [17, 17],
#   'span2': [1, 1]},
#  {'guid': '61b3a65fb908b7599082',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['In',
#    'the',
#    'journal',
#    ',',
#    'Rehnquist',
#    'made',
#    'notes',
#    'on',
#    'what',
#    'he',
#    'was',
#    'reading',
#    '(',
#    '``',
#    'undoubtedly',
#    'Dewey',
#    'does',
#    'not',
#    'wish',
#    'his',
#    'ideas',
#    'carried',
#    'to',
#    'logical',
#    'conclusion',
#    "''",
#    ')',
#    'and',
#    'where',
#    'he',
#    'was',
#    'hiking',
#    ',',
#    'recorded',
#    '``',
#    'poker',
#    'winnings',
#    'of',
#    'a',
#    'dollar',
#    ',',
#    "''",
#    'and',
#    'transcribed',
#    'quotations',
#    'from',
#    ',',
#    'among',
#    'others',
#    ',',
#    'Montesquieu',
#    ',',
#    'Goethe',
#    'and',
#    'Ring',
#    'Lardner',
#    '.'],
#   'span1': [19, 19],
#   'span2': [55, 55]},
#  {'guid': '61b3a65fb9a15bea1140',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['A',
#    'professor',
#    'of',
#    'educational',
#    'psychology',
#    'at',
#    'Spelman',
#    'College',
#    'in',
#    'Atlanta',
#    'in',
#    'the',
#    '1950s',
#    ',',
#    'Young',
#    'wrote',
#    'several',
#    'books',
#    'for',
#    'children',
#    'about',
#    'the',
#    'African-American',
#    'experience',
#    '.'],
#   'span1': [6, 7],
#   'span2': [14, 14]},
#  {'guid': '61b3a65fb93599c4fac9',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'RELIGION',
#   'sentence': ['Mubarak',
#    'expressed',
#    'a',
#    '``',
#    'positive',
#    '...',
#    'approach',
#    'toward',
#    'developing',
#    'bilateral',
#    'relations',
#    ',',
#    "''",
#    'Haddad-Adel',
#    'said',
#    ',',
#    'adding',
#    'that',
#    'for',
#    'his',
#    'own',
#    'part',
#    ',',
#    'he',
#    'stressed',
#    'the',
#    'importance',
#    'of',
#    'also',
#    'strengthening',
#    'economic',
#    'cooperation',
#    'and',
#    'kick-starting',
#    'religious',
#    'dialogue',
#    'between',
#    'the',
#    'predominantly',
#    'Shiite',
#    'Iran',
#    'and',
#    'Sunni',
#    'Egypt',
#    '.'],
#   'span1': [23, 23],
#   'span2': [42, 42]},
#  {'guid': '61b3a65fb9b0c16692f9',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['``',
#    'We',
#    "'re",
#    'glad',
#    'EnergySolutions',
#    'finally',
#    'figured',
#    'out',
#    'what',
#    'Utahans',
#    'have',
#    'said',
#    'for',
#    'two',
#    'years',
#    '--',
#    'that',
#    'Italy',
#    'should',
#    'take',
#    'care',
#    'of',
#    'its',
#    'own',
#    'waste',
#    ',',
#    "''",
#    'said',
#    'Vanessa',
#    'Pierce',
#    ',',
#    'executive',
#    'director',
#    'of',
#    'Healthy',
#    'Environment',
#    'Alliance',
#    'of',
#    'Utah',
#    '.'],
#   'span1': [4, 4],
#   'span2': [28, 29]},
#  {'guid': '61b3a65fb9e4c7b86032',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['Buchwald',
#    'built',
#    'his',
#    'career',
#    'in',
#    'Paris',
#    ',',
#    'where',
#    'he',
#    'wrote',
#    'his',
#    'first',
#    'column',
#    'in',
#    'the',
#    'European',
#    'edition',
#    'of',
#    'the',
#    'New',
#    'York',
#    'Herald',
#    'Tribune',
#    'in',
#    '1949',
#    '.'],
#   'span1': [8, 8],
#   'span2': [10, 10]},
#  {'guid': '61b3a65fb97039e7b13b',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['Matthew',
#    'Dodds',
#    ',',
#    'director',
#    'of',
#    'institutional',
#    'research',
#    'for',
#    'financial',
#    'giant',
#    'Citigroup',
#    'in',
#    'New',
#    'York',
#    ',',
#    'said',
#    'Covidien',
#    'probably',
#    'wo',
#    "n't",
#    'stray',
#    'outside',
#    'of',
#    'its',
#    'four',
#    'areas',
#    'of',
#    'market',
#    'focus',
#    ':',
#    'surgical',
#    'supplies',
#    ',',
#    'oximetry',
#    'monitoring',
#    ',',
#    'vascular',
#    'devices',
#    ',',
#    'and',
#    'specialty',
#    'pharmaceuticals',
#    'such',
#    'as',
#    'pain',
#    'medication',
#    'and',
#    'controlled',
#    'substances',
#    'like',
#    'morphine',
#    'and',
#    'codeine',
#    '.'],
#   'span1': [16, 16],
#   'span2': [0, 1]},
#  {'guid': '61b3a65fb98448b93481',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['``',
#    'A',
#    'great',
#    'VMA',
#    'performance',
#    'would',
#    'have',
#    'probably',
#    'closed',
#    'the',
#    'deal',
#    'for',
#    'her',
#    ',',
#    'but',
#    'she',
#    "'s",
#    'still',
#    'got',
#    'until',
#    'Thanksgiving',
#    'to',
#    'do',
#    'other',
#    'good',
#    'performances',
#    'and',
#    'to',
#    'release',
#    'a',
#    'strong',
#    'album',
#    'with',
#    'other',
#    'hits',
#    'on',
#    'it',
#    ',',
#    "''",
#    'he',
#    'said',
#    '.'],
#   'span1': [39, 39],
#   'span2': [12, 12]},
#  {'guid': '61b3a65fb966e9c2bcab',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['Midfielders',
#    ':',
#    'Mineiro',
#    '(',
#    'Hertha',
#    'Berlin',
#    ')',
#    ',',
#    'Gilberto',
#    'Silva',
#    '(',
#    'Arsenal',
#    ')',
#    ',',
#    'Josue',
#    '(',
#    'Wolfsburg',
#    ')',
#    ',',
#    'Fernando',
#    '(',
#    'Bordeaux',
#    ')',
#    ',',
#    'Elano',
#    '(',
#    'Manchetser',
#    'City',
#    ')',
#    ',',
#    'Kaka',
#    '(',
#    'AC',
#    'Milan',
#    ')',
#    ',',
#    'Diego',
#    '(',
#    'Werder',
#    'Bremen',
#    ')',
#    ',',
#    'Rondaldinio',
#    '(',
#    'FC',
#    'Barcelona',
#    ')',
#    ',',
#    'Julio',
#    'Baptista',
#    '(',
#    'Real',
#    'Madrid',
#    ')',
#    '.'],
#   'span1': [11, 11],
#   'span2': [44, 45]},
#  {'guid': '61b3a65fb901c220b8af',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'PERSON',
#   'sentence': ['McAllister',
#    'said',
#    'he',
#    'has',
#    'never',
#    'heard',
#    'Palin',
#    'reprise',
#    'those',
#    '1997',
#    'remarks',
#    'about',
#    'dinosaurs',
#    'and',
#    'that',
#    'Palin',
#    'has',
#    'preferred',
#    'not',
#    'to',
#    'discuss',
#    'her',
#    'views',
#    'on',
#    'evolution',
#    'publicly',
#    '--',
#    'though',
#    'a',
#    'former',
#    'campaign',
#    'aide',
#    'said',
#    'that',
#    'Palin',
#    'privately',
#    'made',
#    'a',
#    'similar',
#    'reference',
#    'during',
#    'her',
#    '2006',
#    'race',
#    'for',
#    'Alaska',
#    'governor',
#    '.'],
#   'span1': [0, 0],
#   'span2': [34, 34]},
#  {'guid': '61b3a65fb91acc0ec5aa',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'DATE',
#   'sentence': ['In',
#    'an',
#    'op-ed',
#    'Sunday',
#    'in',
#    'the',
#    'Washington',
#    'Post',
#    ',',
#    'Gonzales',
#    'apologized',
#    'for',
#    'the',
#    'handling',
#    'of',
#    'the',
#    'matter',
#    ',',
#    'including',
#    'a',
#    'series',
#    'of',
#    'misstatements',
#    'about',
#    'his',
#    'exact',
#    'role',
#    'that',
#    'he',
#    'acknowledged',
#    '``',
#    'created',
#    'confusion',
#    '.',
#    "''"],
#   'span1': [24, 24],
#   'span2': [3, 3]},
#  {'guid': '61b3a65fb97a5129ab0d',
#   'label': 'no_relation',
#   'ner1': 'PERSON',
#   'ner2': 'NUMBER',
#   'sentence': ['Lee',
#    ',',
#    'who',
#    'rushed',
#    'to',
#    'the',
#    'scene',
#    'from',
#    'Taipei',
#    'City',
#    'upon',
#    'being',
#    'informed',
#    'of',
#    'the',
#    'accident',
#    ',',
#    'said',
#    'nine',
#    'other',
#    'Singaporean',
#    'soldiers',
#    'on',
#    'the',
#    'ground',
#    'were',
#    'wounded',
#    'in',
#    'the',
#    'crash',
#    ',',
#    'one',
#    'of',
#    'whom',
#    'suffered',
#    'serious',
#    'burns',
#    'and',
#    'was',
#    'taken',
#    'to',
#    'the',
#    'Tri-Service',
#    'General',
#    'Hospital',
#    'in',
#    'Taipei',
#    '.'],
#   'span1': [0, 0],
#   'span2': [31, 31]},
#  {'guid': '61b3a65fb9dead3b7068',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'ORGANIZATION',
#   'sentence': ['A',
#    'Fidelity',
#    'Investments',
#    'spokeswoman',
#    ',',
#    'Anne',
#    'Crowley',
#    ',',
#    'said',
#    'that',
#    'many',
#    'of',
#    'the',
#    'Fidelity',
#    'funds',
#    'cited',
#    'by',
#    'the',
#    'activists',
#    'are',
#    'run',
#    'by',
#    'Fidelity',
#    'International',
#    'Ltd.',
#    ',',
#    'a',
#    'separate',
#    'company',
#    'in',
#    'London',
#    'with',
#    'some',
#    'common',
#    'ownership',
#    '.'],
#   'span1': [13, 13],
#   'span2': [22, 24]},
#  {'guid': '61b3a65fb991169a9b7b',
#   'label': 'no_relation',
#   'ner1': 'ORGANIZATION',
#   'ner2': 'PERSON',
#   'sentence': ['Utah',
#    'Gov.',
#    'Jon',
#    'Huntsman',
#    'is',
#    'using',
#    'an',
#    'interstate',
#    'compact',
#    'to',
#    'block',
#    'the',
#    'waste',
#    'from',
#    'coming',
#    'to',
#    'his',
#    'state',
#    'if',
#    'EnergySolutions',
#    "'",
#    'application',
#    'is',
#    'approved',
#    '.'],
#   'span1': [19, 19],
#   'span2': [16, 16]},
#  ...]

# %%
conll04_train_examples = read_json(conll04_train_path)
conll04_train_examples
# Out:
# [{'tokens': ['Newspaper',
#    '`',
#    'Explains',
#    "'",
#    'U.S.',
#    'Interests',
#    'Section',
#    'Events',
#    'FL1402001894',
#    'Havana',
#    'Radio',
#    'Reloj',
#    'Network',
#    'in',
#    'Spanish',
#    '2100',
#    'GMT',
#    '13',
#    'Feb',
#    '94'],
#   'entities': [{'type': 'Loc', 'start': 4, 'end': 5},
#    {'type': 'Loc', 'start': 9, 'end': 10},
#    {'type': 'Org', 'start': 10, 'end': 13},
#    {'type': 'Other', 'start': 15, 'end': 17},
#    {'type': 'Other', 'start': 17, 'end': 20}],
#   'relations': [{'type': 'OrgBased_In', 'head': 2, 'tail': 1}],
#   'orig_id': 3255},
#  {'tokens': ['`',
#    '`',
#    'If',
#    'it',
#    'does',
#    'not',
#    'snow',
#    ',',
#    'and',
#    'a',
#    'lot',
#    ',',
#    'within',
#    'this',
#    'month',
#    'we',
#    'will',
#    'have',
#    'no',
#    'water',
#    'to',
#    'submerge',
#    '150',
#    ',',
#    '000',
#    'hectares',
#    '(',
#    '370',
#    ',',
#    '500',
#    'acres',
#    ')',
#    'of',
#    'rice',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Bruno',
#    'Pusterla',
#    ',',
#    'a',
#    'top',
#    'official',
#    'of',
#    'the',
#    'Italian',
#    'Agricultural',
#    'Confederation',
#    '.'],
#   'entities': [{'type': 'Other', 'start': 22, 'end': 26},
#    {'type': 'Other', 'start': 27, 'end': 31},
#    {'type': 'Other', 'start': 33, 'end': 34},
#    {'type': 'Peop', 'start': 38, 'end': 40},
#    {'type': 'Org', 'start': 46, 'end': 49}],
#   'relations': [{'type': 'Work_For', 'head': 3, 'tail': 4}],
#   'orig_id': 95},
#  {'tokens': ['The',
#    'self-propelled',
#    'rig',
#    'Avco',
#    '5',
#    'was',
#    'headed',
#    'to',
#    'shore',
#    'with',
#    '14',
#    'people',
#    'aboard',
#    'early',
#    'Monday',
#    'when',
#    'it',
#    'capsized',
#    'about',
#    '20',
#    'miles',
#    'off',
#    'the',
#    'Louisiana',
#    'coast',
#    ',',
#    'near',
#    'Morgan',
#    'City',
#    ',',
#    'Lifa',
#    'said.'],
#   'entities': [{'type': 'Other', 'start': 19, 'end': 21},
#    {'type': 'Loc', 'start': 23, 'end': 24},
#    {'type': 'Loc', 'start': 27, 'end': 29},
#    {'type': 'Peop', 'start': 30, 'end': 31}],
#   'relations': [{'type': 'Located_In', 'head': 2, 'tail': 1}],
#   'orig_id': 2447},
#  {'tokens': ['Annie',
#    'Oakley',
#    ',',
#    'also',
#    'known',
#    'as',
#    'Little',
#    'Miss',
#    'Sure',
#    'Shot',
#    ',',
#    'was',
#    'born',
#    'Phoebe',
#    'Ann',
#    'Moses',
#    'in',
#    'Willowdell',
#    ',',
#    'Darke',
#    'County',
#    ',',
#    'in',
#    '1860',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Peop', 'start': 6, 'end': 10},
#    {'type': 'Peop', 'start': 13, 'end': 16},
#    {'type': 'Loc', 'start': 17, 'end': 21}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 3},
#    {'type': 'Live_In', 'head': 1, 'tail': 3},
#    {'type': 'Live_In', 'head': 2, 'tail': 3}],
#   'orig_id': 5284},
#  {'tokens': ['Penry',
#    'raped',
#    'Pamela',
#    'Moseley',
#    'Carpenter',
#    'on',
#    'Oct.',
#    '15',
#    ',',
#    '1979',
#    ',',
#    'in',
#    'Livingston',
#    ',',
#    'Texas',
#    ',',
#    'then',
#    'stabbed',
#    'her',
#    'to',
#    'death',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 2, 'end': 5},
#    {'type': 'Other', 'start': 6, 'end': 10},
#    {'type': 'Loc', 'start': 12, 'end': 13},
#    {'type': 'Loc', 'start': 14, 'end': 15}],
#   'relations': [{'type': 'Located_In', 'head': 3, 'tail': 4}],
#   'orig_id': 210},
#  {'tokens': ['Anhui',
#    '`',
#    'Surplus',
#    "'",
#    'Rural',
#    'Laborers',
#    'Move',
#    'to',
#    'Cities',
#    'OW1102132994',
#    'Beijing',
#    'XINHUA',
#    'in',
#    'English',
#    '1313',
#    'GMT',
#    '11',
#    'Feb',
#    '94'],
#   'entities': [{'type': 'Loc', 'start': 10, 'end': 11},
#    {'type': 'Org', 'start': 11, 'end': 12},
#    {'type': 'Other', 'start': 14, 'end': 16},
#    {'type': 'Other', 'start': 16, 'end': 19}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3082},
#  {'tokens': ['Meanwhile',
#    ',',
#    'Shi',
#    'Liming',
#    'at',
#    'the',
#    'Institute',
#    'of',
#    'Zoology',
#    'of',
#    'Kunming',
#    'found',
#    'that',
#    'pandas',
#    'lack',
#    'variety',
#    'in',
#    'their',
#    'protein',
#    'heredity',
#    ',',
#    'which',
#    'may',
#    'serve',
#    'as',
#    'one',
#    'of',
#    'the',
#    'major',
#    'reasons',
#    'for',
#    'pandas',
#    "'",
#    'near',
#    'extinction',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 2, 'end': 4},
#    {'type': 'Org', 'start': 6, 'end': 9},
#    {'type': 'Loc', 'start': 10, 'end': 11}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 1, 'tail': 2}],
#   'orig_id': 4605},
#  {'tokens': ['Here',
#    'are',
#    'highlights',
#    'of',
#    'Lucille',
#    'Ball',
#    "'s",
#    'career',
#    ':',
#    '1911',
#    '_',
#    'Born',
#    'Aug.',
#    '6',
#    ',',
#    '1911',
#    'in',
#    'Jamestown',
#    'N.Y.',
#    ',',
#    'the',
#    'daughter',
#    'of',
#    'an',
#    'electrician',
#    'and',
#    'concert',
#    'pianist',
#    'Desiree',
#    'Ball.',
#    '1926'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Other', 'start': 12, 'end': 13},
#    {'type': 'Loc', 'start': 17, 'end': 19},
#    {'type': 'Peop', 'start': 28, 'end': 30}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 2}],
#   'orig_id': 5332},
#  {'tokens': ['John',
#    'Wilkes',
#    'Booth',
#    'wasn',
#    "'t",
#    'a',
#    'shiftless',
#    'actor',
#    'who',
#    'killed',
#    'Abraham',
#    'Lincoln',
#    'out',
#    'of',
#    'despondency',
#    'over',
#    'the',
#    'South',
#    "'s",
#    'loss',
#    'in',
#    'the',
#    'Civil',
#    'War',
#    ',',
#    'but',
#    'a',
#    'Confederate',
#    'intelligence',
#    'agent',
#    ',',
#    'a',
#    'new',
#    'book',
#    'contends',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 3},
#    {'type': 'Peop', 'start': 10, 'end': 12},
#    {'type': 'Other', 'start': 22, 'end': 24}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 1}],
#   'orig_id': 5062},
#  {'tokens': ['The',
#    'viewers',
#    'of',
#    '"',
#    'JFK',
#    '"',
#    'and',
#    '"',
#    'The',
#    'Men',
#    'Who',
#    'Killed',
#    'Kennedy',
#    '"',
#    'never',
#    'learn',
#    'about',
#    'these',
#    'facts',
#    ',',
#    'nor',
#    'do',
#    'they',
#    'ever',
#    'learn',
#    'about',
#    'all',
#    'of',
#    'the',
#    'other',
#    'massive',
#    'body',
#    'of',
#    'evidence',
#    'that',
#    'conclusively',
#    'proves',
#    'beyond',
#    'a',
#    'reasonable',
#    'doubt',
#    'that',
#    'Oswald',
#    'was',
#    'the',
#    'lone',
#    'gunman',
#    'who',
#    'killed',
#    'President',
#    'Kennedy',
#    'and',
#    'Officer',
#    'Tippit',
#    'and',
#    'that',
#    'there',
#    'was',
#    'no',
#    'coverup',
#    'by',
#    'Earl',
#    'Warren',
#    'or',
#    'by',
#    'the',
#    'Warren',
#    'Commission.',
#    ';'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 5},
#    {'type': 'Other', 'start': 11, 'end': 13},
#    {'type': 'Peop', 'start': 42, 'end': 43},
#    {'type': 'Peop', 'start': 49, 'end': 51},
#    {'type': 'Peop', 'start': 52, 'end': 54},
#    {'type': 'Peop', 'start': 61, 'end': 63},
#    {'type': 'Org', 'start': 66, 'end': 68}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 3},
#    {'type': 'Kill', 'head': 2, 'tail': 4}],
#   'orig_id': 5235},
#  {'tokens': ['For',
#    'singer',
#    'and',
#    'guitarist',
#    'Bob',
#    'Boyd',
#    ',',
#    '57',
#    ',',
#    'the',
#    'Ranch',
#    'has',
#    'been',
#    'home',
#    'since',
#    'he',
#    'left',
#    'Chattanooga',
#    ',',
#    'Tenn.',
#    ',',
#    '35',
#    'years',
#    'ago',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 17, 'end': 18},
#    {'type': 'Loc', 'start': 19, 'end': 20},
#    {'type': 'Other', 'start': 21, 'end': 23}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1},
#    {'type': 'Live_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 327},
#  {'tokens': ['Rome',
#    'is',
#    'in',
#    'Lazio',
#    'province',
#    'and',
#    'Naples',
#    'in',
#    'Campania',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 3, 'end': 4},
#    {'type': 'Loc', 'start': 6, 'end': 7},
#    {'type': 'Loc', 'start': 8, 'end': 9}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1},
#    {'type': 'Located_In', 'head': 2, 'tail': 3}],
#   'orig_id': 28},
#  {'tokens': ['He',
#    'has',
#    'been',
#    'the',
#    'State',
#    'Department',
#    "'s",
#    'refugee',
#    'coordinator',
#    'and',
#    'is',
#    'a',
#    'former',
#    'Harvard',
#    'politics',
#    'professor.',
#    '_Ronald',
#    'for',
#    'the',
#    'rank',
#    'of',
#    'ambassador',
#    'during',
#    'his',
#    'tenure',
#    'as',
#    'U.S.',
#    'negotiator',
#    'on',
#    'textile',
#    'matters.'],
#   'entities': [{'type': 'Org', 'start': 4, 'end': 6},
#    {'type': 'Org', 'start': 13, 'end': 14},
#    {'type': 'Loc', 'start': 26, 'end': 27}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 2},
#    {'type': 'OrgBased_In', 'head': 1, 'tail': 2}],
#   'orig_id': 2415},
#  {'tokens': ['(',
#    'By',
#    'ITAR-TASS',
#    'correspondent',
#    'Mikhail',
#    'Shevtsov',
#    ')'],
#   'entities': [{'type': 'Org', 'start': 2, 'end': 3},
#    {'type': 'Peop', 'start': 4, 'end': 6}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 0}],
#   'orig_id': 3886},
#  {'tokens': ['It',
#    'is',
#    'not',
#    'and',
#    'never',
#    'has',
#    'been',
#    'designed',
#    'or',
#    'advertised',
#    'as',
#    'a',
#    'threatening',
#    'or',
#    'abusive',
#    'type',
#    'of',
#    'thing',
#    ',',
#    "'",
#    "'",
#    'said',
#    'XBT',
#    'spokesman',
#    'Allan',
#    'Fitzmaurice.'],
#   'entities': [{'type': 'Org', 'start': 22, 'end': 23},
#    {'type': 'Peop', 'start': 24, 'end': 26}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 0}],
#   'orig_id': 2155},
#  {'tokens': ['In',
#    '1752',
#    ',',
#    'flagmaker',
#    'Betsy',
#    'Ross',
#    'was',
#    'born',
#    'in',
#    'Philadelphia',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 9, 'end': 10}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5310},
#  {'tokens': ['Fire',
#    'Island',
#    'National',
#    'Seashore',
#    ',',
#    'Patchogue',
#    ',',
#    'N.Y.',
#    ';'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 4},
#    {'type': 'Loc', 'start': 5, 'end': 6},
#    {'type': 'Loc', 'start': 7, 'end': 8}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1},
#    {'type': 'Located_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 135},
#  {'tokens': ['OW3004022094',
#    'Beijing',
#    'XINHUA',
#    'Domestic',
#    'Service',
#    'in',
#    'Chinese',
#    '1149',
#    'GMT',
#    '29',
#    'Apr',
#    '94'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Org', 'start': 2, 'end': 3},
#    {'type': 'Other', 'start': 7, 'end': 9},
#    {'type': 'Other', 'start': 9, 'end': 12}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 4293},
#  {'tokens': ['In',
#    'Idaho',
#    ',',
#    'where',
#    '76',
#    ',',
#    '000',
#    'acres',
#    'have',
#    'been',
#    'blackened',
#    ',',
#    'smoke',
#    'from',
#    'fires',
#    'miles',
#    'away',
#    'hung',
#    'over',
#    'Boise',
#    'but',
#    'no',
#    'warnings',
#    'were',
#    'issued',
#    'to',
#    'stay',
#    'indoors.'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Other', 'start': 4, 'end': 8},
#    {'type': 'Loc', 'start': 19, 'end': 20}],
#   'relations': [{'type': 'Located_In', 'head': 2, 'tail': 0}],
#   'orig_id': 2547},
#  {'tokens': ['The',
#    'strong',
#    'Santa',
#    'Ana',
#    'winds',
#    'that',
#    'earlier',
#    'produced',
#    'wind',
#    'gusts',
#    'as',
#    'high',
#    'as',
#    '100',
#    'mph',
#    'in',
#    'Southern',
#    'California',
#    ',',
#    'destroying',
#    'a',
#    'blimp',
#    ',',
#    'shutting',
#    'down',
#    'an',
#    'airport',
#    ',',
#    'and',
#    'cutting',
#    'power',
#    'to',
#    'thousands',
#    'of',
#    'utility',
#    'customers',
#    'were',
#    'subsiding',
#    ',',
#    'officials',
#    'said',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 2, 'end': 4},
#    {'type': 'Other', 'start': 13, 'end': 15},
#    {'type': 'Loc', 'start': 16, 'end': 18}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 2}],
#   'orig_id': 1030},
#  {'tokens': ['But',
#    'Sen.',
#    'Strom',
#    'Thurmond',
#    ',',
#    'R-S.C.',
#    ',',
#    'sponsor',
#    'of',
#    'a',
#    'proposed',
#    'constitutional',
#    'amendment',
#    ',',
#    'said',
#    ',',
#    '`',
#    '`',
#    'An',
#    'overwhelming',
#    'majority',
#    'of',
#    'Americans',
#    'are',
#    'looking',
#    'to',
#    'the',
#    'Congress',
#    'to',
#    '...',
#    'restore',
#    'the',
#    'proper',
#    'civil',
#    'respect',
#    'for',
#    'our',
#    'American',
#    'flag.',
#    "'",
#    "'"],
#   'entities': [{'type': 'Peop', 'start': 2, 'end': 4},
#    {'type': 'Other', 'start': 22, 'end': 23},
#    {'type': 'Org', 'start': 27, 'end': 28}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 2}],
#   'orig_id': 2274},
#  {'tokens': ['With',
#    'considerable',
#    'rough',
#    'sailing',
#    'and',
#    'difficulty',
#    'anticipated',
#    'in',
#    'the',
#    'process',
#    'of',
#    'ratification',
#    'by',
#    'the',
#    'U.S.',
#    'Congress',
#    ',',
#    'the',
#    'Congress',
#    'is',
#    'hardly',
#    'expected',
#    'to',
#    'complete',
#    'the',
#    'ratification',
#    'process',
#    'within',
#    'the',
#    'time',
#    'limit',
#    'set',
#    'by',
#    'the',
#    'UR',
#    'agreement',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 14, 'end': 15},
#    {'type': 'Org', 'start': 15, 'end': 16},
#    {'type': 'Org', 'start': 18, 'end': 19}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 0}],
#   'orig_id': 4051},
#  {'tokens': ['In',
#    'another',
#    'scene',
#    ',',
#    'President',
#    'James',
#    'Garfield',
#    "'s",
#    'assassin',
#    'Charles',
#    'Guiteau',
#    '(',
#    'Jonathan',
#    'Hadary',
#    ')',
#    'prances',
#    'up',
#    'and',
#    'down',
#    'the',
#    'stairs',
#    'of',
#    'the',
#    'gallows',
#    'where',
#    'he',
#    'will',
#    'be',
#    'hanged',
#    ',',
#    'all',
#    'the',
#    'while',
#    'singing',
#    'a',
#    'spirited',
#    'Gospel',
#    'tune',
#    'about',
#    '"',
#    'going',
#    'to',
#    'the',
#    'Lordy',
#    '.',
#    '"'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 7},
#    {'type': 'Peop', 'start': 9, 'end': 11},
#    {'type': 'Peop', 'start': 12, 'end': 14},
#    {'type': 'Other', 'start': 36, 'end': 37},
#    {'type': 'Other', 'start': 43, 'end': 44}],
#   'relations': [{'type': 'Kill', 'head': 1, 'tail': 0}],
#   'orig_id': 5239},
#  {'tokens': ['SPACE', 'CENTER', ',', 'Houston', '(', 'AP', ')'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 3, 'end': 4},
#    {'type': 'Org', 'start': 5, 'end': 6}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1}],
#   'orig_id': 355},
#  {'tokens': ['Grant',
#    'B.',
#    'Cooper',
#    ',',
#    'an',
#    'attorney',
#    'who',
#    'defended',
#    'Kennedy',
#    'assassin',
#    'Sirhan',
#    'B.',
#    'Sirhan',
#    ',',
#    'has',
#    'died',
#    'at',
#    'age',
#    '87.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 3},
#    {'type': 'Peop', 'start': 8, 'end': 9},
#    {'type': 'Peop', 'start': 10, 'end': 13}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 1}],
#   'orig_id': 5138},
#  {'tokens': ['Woodrow',
#    'Wilson',
#    '(',
#    '28th',
#    'President',
#    ')',
#    ':',
#    'Born',
#    'at',
#    'about',
#    'midnight',
#    ',',
#    'leaving',
#    'the',
#    'date',
#    'in',
#    'doubt',
#    ',',
#    'Dec.',
#    '28',
#    'or',
#    '29',
#    ',',
#    '1856',
#    ',',
#    'in',
#    'a',
#    'Presbyterian',
#    'manse',
#    'in',
#    'Staunton',
#    ',',
#    'Va',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Other', 'start': 18, 'end': 19},
#    {'type': 'Loc', 'start': 30, 'end': 33}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 2}],
#   'orig_id': 5399},
#  {'tokens': ['`',
#    '`',
#    'I',
#    "'m",
#    'delighted',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Peter',
#    'Butler',
#    ',',
#    'attorney',
#    'for',
#    'A.',
#    'Copeland',
#    'Enterprises',
#    'Inc.',
#    '_',
#    'the',
#    'company',
#    'which',
#    'owns',
#    'New',
#    'Orleans-based',
#    'Popeyes',
#    'Famous',
#    'Fried',
#    'Chicken',
#    '_',
#    'after',
#    'Judge',
#    'Henry',
#    'A.',
#    'Politz',
#    'announced',
#    'the',
#    'decision',
#    'for',
#    'the',
#    'three-judge',
#    '5th',
#    'U.S.',
#    'Circuit',
#    'Court',
#    'of',
#    'Appeals',
#    'panel',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 9, 'end': 11},
#    {'type': 'Org', 'start': 14, 'end': 18},
#    {'type': 'Org', 'start': 25, 'end': 29},
#    {'type': 'Peop', 'start': 32, 'end': 35},
#    {'type': 'Org', 'start': 41, 'end': 47}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1},
#    {'type': 'Work_For', 'head': 3, 'tail': 4}],
#   'orig_id': 1389},
#  {'tokens': ['PURCHASE', ',', 'N.Y', '.'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 2, 'end': 4}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1}],
#   'orig_id': 1336},
#  {'tokens': ['In',
#    '1782',
#    ',',
#    'the',
#    'first',
#    'president',
#    'who',
#    'was',
#    'a',
#    'native',
#    'citizen',
#    'of',
#    'the',
#    'United',
#    'States',
#    ',',
#    'Martin',
#    'Van',
#    'Buren',
#    ',',
#    'was',
#    'born',
#    'in',
#    'Kinderhook',
#    ',',
#    'N.Y.',
#    'In',
#    '1791',
#    ',',
#    'composer',
#    'Wolfgang',
#    'Amadeus',
#    'Mozart',
#    'died',
#    'in',
#    'Vienna',
#    ',',
#    'Austria',
#    ',',
#    'at',
#    'the',
#    'age',
#    'of',
#    '35',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 13, 'end': 15},
#    {'type': 'Peop', 'start': 16, 'end': 19},
#    {'type': 'Loc', 'start': 23, 'end': 26},
#    {'type': 'Peop', 'start': 30, 'end': 33},
#    {'type': 'Loc', 'start': 35, 'end': 38}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 2}],
#   'orig_id': 5306},
#  {'tokens': ['U.S.',
#    'Coast',
#    'Guard',
#    'Training',
#    'Center',
#    ',',
#    'Petaluma',
#    ',',
#    'Calif.',
#    ';'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 5},
#    {'type': 'Loc', 'start': 6, 'end': 7},
#    {'type': 'Loc', 'start': 8, 'end': 9}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 140},
#  {'tokens': ['PM2303111794',
#    'Moscow',
#    'IZVESTIYA',
#    'in',
#    'Russian',
#    '23',
#    'Mar',
#    '94',
#    'p',
#    '3'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Org', 'start': 2, 'end': 3},
#    {'type': 'Other', 'start': 5, 'end': 8}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3929},
#  {'tokens': ['Pepperell',
#    ',',
#    'based',
#    'in',
#    'West',
#    'Point',
#    ',',
#    'Ga.',
#    ',',
#    'manufactures',
#    'Martex',
#    'towels',
#    'and',
#    'Arrow',
#    'shirts',
#    'and',
#    'has',
#    'about',
#    'a',
#    'quarter',
#    'of',
#    'the',
#    'nation',
#    "'s",
#    'home',
#    'fashion',
#    'textile',
#    'market',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 7, 'end': 8}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 1294},
#  {'tokens': ['In',
#    'a',
#    'brief',
#    'order',
#    ',',
#    'the',
#    'justices',
#    'refused',
#    'to',
#    'reinstate',
#    'the',
#    'death',
#    'sentence',
#    'of',
#    'John',
#    'Harvey',
#    'Adamson',
#    ',',
#    'who',
#    'was',
#    'convicted',
#    'of',
#    'murdering',
#    'Phoenix',
#    'newspaper',
#    'reporter',
#    'Don',
#    'Bolles',
#    'in',
#    '1976',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 14, 'end': 17},
#    {'type': 'Loc', 'start': 23, 'end': 24},
#    {'type': 'Peop', 'start': 26, 'end': 28}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 2}],
#   'orig_id': 5195},
#  {'tokens': ['Michael',
#    'R.',
#    'Gordon',
#    ',',
#    'chairman',
#    'of',
#    'the',
#    'Montgomery',
#    'County',
#    'House',
#    'delegation',
#    ',',
#    'thinks',
#    'Ms.',
#    'Toth',
#    'is',
#    'in',
#    'an',
#    '`',
#    '`',
#    'embarrassing',
#    "'",
#    "'",
#    'position',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 3},
#    {'type': 'Org', 'start': 7, 'end': 11},
#    {'type': 'Peop', 'start': 13, 'end': 15}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 495},
#  {'tokens': ['(',
#    'Text',
#    ')',
#    'Vyacheslav',
#    'Chornovil',
#    ',',
#    'leader',
#    'of',
#    'the',
#    'Ukrainian',
#    'Popular',
#    'Rukh',
#    ',',
#    'intends',
#    'to',
#    'run',
#    'for',
#    'the',
#    'presidency',
#    'in',
#    'the',
#    '26',
#    'June',
#    ',',
#    '1994',
#    'elections',
#    ',',
#    'officials',
#    'in',
#    'the',
#    'Rukh',
#    'press',
#    'service',
#    'told',
#    'INTERFAX-Ukraine',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 3, 'end': 5},
#    {'type': 'Org', 'start': 9, 'end': 12},
#    {'type': 'Other', 'start': 21, 'end': 25},
#    {'type': 'Org', 'start': 30, 'end': 32},
#    {'type': 'Org', 'start': 34, 'end': 35}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 2970},
#  {'tokens': ['Slavko',
#    'Mestrovic',
#    ',',
#    'secretary',
#    'of',
#    'the',
#    'Croatian',
#    'People',
#    "'s",
#    'Party',
#    ',',
#    'welcomes',
#    'the',
#    'deceleration',
#    'in',
#    'the',
#    'case',
#    'if',
#    'it',
#    'leads',
#    'toward',
#    'a',
#    'just',
#    'peace',
#    ',',
#    'the',
#    'reintegration',
#    'of',
#    'the',
#    'occupied',
#    'Croatian',
#    'territories',
#    ',',
#    'the',
#    'return',
#    'of',
#    'the',
#    'refugees',
#    'to',
#    'their',
#    'homes',
#    ',',
#    'and',
#    'the',
#    'cessation',
#    'of',
#    'the',
#    'war',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Org', 'start': 6, 'end': 10}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 3200},
#  {'tokens': ['CDT',
#    'Tuesday',
#    'in',
#    'the',
#    'area',
#    'of',
#    'Port',
#    'Arther',
#    'and',
#    'Galveston',
#    ',',
#    'Texas.'],
#   'entities': [{'type': 'Loc', 'start': 6, 'end': 8},
#    {'type': 'Loc', 'start': 9, 'end': 10},
#    {'type': 'Loc', 'start': 11, 'end': 12}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 1486},
#  {'tokens': ['KAL',
#    'attorney',
#    'George',
#    'Tompkins',
#    'countered',
#    'that',
#    'the',
#    'main',
#    'evidence',
#    'in',
#    'the',
#    'case',
#    'is',
#    'a',
#    'line',
#    'drawn',
#    'by',
#    'Soviet',
#    'officials',
#    'on',
#    'a',
#    'map',
#    'showing',
#    'an',
#    'off-course',
#    'Flight',
#    '007',
#    'flying',
#    'for',
#    'several',
#    'hours',
#    'over',
#    'Russian',
#    'airspace',
#    'hundreds',
#    'of',
#    'miles',
#    'to',
#    'the',
#    'west',
#    'of',
#    'its',
#    'planned',
#    'route.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 2, 'end': 4},
#    {'type': 'Loc', 'start': 17, 'end': 18},
#    {'type': 'Other', 'start': 25, 'end': 27}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 0}],
#   'orig_id': 2232},
#  {'tokens': ['Jacobs',
#    ',',
#    '20',
#    ',',
#    'and',
#    'Eddie',
#    'Hatcher',
#    ',',
#    '31',
#    ',',
#    'were',
#    'charged',
#    'in',
#    'the',
#    '1988',
#    'takeover',
#    'in',
#    'Lumberton',
#    ',',
#    'N.C.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 5, 'end': 7},
#    {'type': 'Loc', 'start': 17, 'end': 18},
#    {'type': 'Loc', 'start': 19, 'end': 20}],
#   'relations': [{'type': 'Located_In', 'head': 2, 'tail': 3}],
#   'orig_id': 517},
#  {'tokens': ['Jack',
#    'Ruby',
#    'bought',
#    'the',
#    'revolver',
#    'for',
#    '$62.50',
#    'in',
#    'a',
#    'Dallas',
#    'gun',
#    'shop',
#    'and',
#    'used',
#    'it',
#    'to',
#    'shoot',
#    'Oswald',
#    'two',
#    'days',
#    'after',
#    'Kennedy',
#    'was',
#    'assassinated.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 9, 'end': 10},
#    {'type': 'Peop', 'start': 17, 'end': 18},
#    {'type': 'Peop', 'start': 21, 'end': 22}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 2}],
#   'orig_id': 5158},
#  {'tokens': ['In',
#    'the',
#    'communique',
#    ',',
#    'the',
#    'Group',
#    'of',
#    'Rio',
#    'states',
#    'that',
#    '"',
#    'the',
#    'Haitian',
#    'crisis',
#    'can',
#    'be',
#    'resolved',
#    'only',
#    'if',
#    'unrestricted',
#    'respect',
#    'is',
#    'shown',
#    'for',
#    'the',
#    'Governor',
#    "'s",
#    'Island',
#    'Agreement',
#    'which',
#    'calls',
#    'for',
#    'the',
#    'prompt',
#    'return',
#    'of',
#    'Haitian',
#    'President',
#    'Jean',
#    'Bertrand',
#    'Aristide',
#    'to',
#    'the',
#    'exercise',
#    'of',
#    'his',
#    'constitutional',
#    'powers',
#    'in',
#    'Haiti',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 5, 'end': 8},
#    {'type': 'Peop', 'start': 38, 'end': 41},
#    {'type': 'Loc', 'start': 49, 'end': 50}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 2}],
#   'orig_id': 4385},
#  {'tokens': ['In',
#    '1882',
#    ',',
#    'the',
#    'notorious',
#    'outlaw',
#    'Jesse',
#    'James',
#    'was',
#    'shot',
#    'to',
#    'death',
#    'in',
#    'St.',
#    'Joseph',
#    ',',
#    'Mo.',
#    ',',
#    'by',
#    'Robert',
#    'Ford',
#    ',',
#    'a',
#    'member',
#    'of',
#    'his',
#    'own',
#    'gang',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 6, 'end': 8},
#    {'type': 'Loc', 'start': 13, 'end': 17},
#    {'type': 'Peop', 'start': 19, 'end': 21}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 0}],
#   'orig_id': 5129},
#  {'tokens': ['Robert',
#    'Bernero',
#    ',',
#    'chief',
#    'of',
#    'waste',
#    'disposal',
#    'for',
#    'the',
#    'NRC',
#    ',',
#    'said',
#    'the',
#    'shafts',
#    'would',
#    'be',
#    '`',
#    '`',
#    'the',
#    'first',
#    'major',
#    'holes',
#    'to',
#    'be',
#    'dug',
#    'into',
#    'the',
#    'Yucca',
#    'Mountain',
#    'formation.',
#    "'",
#    "'"],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Org', 'start': 9, 'end': 10},
#    {'type': 'Loc', 'start': 27, 'end': 29}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 2068},
#  {'tokens': ['Datuk',
#    'Sri',
#    'Dr.',
#    'Mahathir',
#    'said',
#    'the',
#    'two',
#    'leaders',
#    'had',
#    'invited',
#    'him',
#    'to',
#    'make',
#    'an',
#    'official',
#    'visit',
#    'to',
#    'South',
#    'Africa',
#    'and',
#    'he',
#    'also',
#    'had',
#    'extended',
#    'invitations',
#    'to',
#    'the',
#    'two',
#    'to',
#    'make',
#    'a',
#    'similar',
#    'visit',
#    'to',
#    'Malaysia',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 4},
#    {'type': 'Loc', 'start': 17, 'end': 19},
#    {'type': 'Loc', 'start': 34, 'end': 35}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 2}],
#   'orig_id': 4308},
#  {'tokens': ['SAN', 'FRANCISCO', '(', 'AP', ')'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 2},
#    {'type': 'Org', 'start': 3, 'end': 4}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 1746},
#  {'tokens': ['Moscow', 'ITAR-TASS'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Org', 'start': 1, 'end': 2}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 2952},
#  {'tokens': ['The',
#    'Environmental',
#    'Protection',
#    'Agency',
#    'is',
#    'working',
#    'on',
#    'a',
#    'brochure',
#    'advising',
#    'diabetics',
#    'of',
#    'the',
#    'best',
#    'way',
#    'to',
#    'dispose',
#    'of',
#    'needles',
#    ',',
#    'said',
#    'Robin',
#    'Woods',
#    ',',
#    'a',
#    'spokeswoman',
#    'for',
#    'the',
#    'agency',
#    'in',
#    'Washington',
#    ',',
#    'D.C.',
#    'It',
#    'will',
#    'suggest',
#    'that',
#    'diabetics',
#    'place',
#    '`',
#    '`',
#    'sharps',
#    "'",
#    "'",
#    '_',
#    'the',
#    'needle',
#    'end',
#    'of',
#    'a',
#    'syringe',
#    '_',
#    'in',
#    'a',
#    'hard',
#    'plastic',
#    'or',
#    'metal',
#    'container',
#    'like',
#    'a',
#    'coffee',
#    'can',
#    'before',
#    'throwing',
#    'it',
#    'in',
#    'the',
#    'trash',
#    ',',
#    'Woods',
#    'said.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 4},
#    {'type': 'Peop', 'start': 21, 'end': 23},
#    {'type': 'Loc', 'start': 30, 'end': 33},
#    {'type': 'Peop', 'start': 70, 'end': 71}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 2},
#    {'type': 'Work_For', 'head': 1, 'tail': 0},
#    {'type': 'Work_For', 'head': 3, 'tail': 0}],
#   'orig_id': 1615},
#  {'tokens': ['True',
#    ',',
#    'Woodrow',
#    'Wilson',
#    'was',
#    'born',
#    'in',
#    'Virginia',
#    ',',
#    'but',
#    'he',
#    'won',
#    'his',
#    'political',
#    'fame',
#    'as',
#    'governor',
#    'of',
#    'New',
#    'Jersey',
#    ',',
#    'so',
#    'he',
#    'hardly',
#    'counted',
#    'as',
#    'a',
#    'Southerner',
#    'in',
#    'political',
#    'terms',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 2, 'end': 4},
#    {'type': 'Loc', 'start': 7, 'end': 8},
#    {'type': 'Loc', 'start': 18, 'end': 20},
#    {'type': 'Other', 'start': 27, 'end': 28}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5419},
#  {'tokens': ['`',
#    '`',
#    'You',
#    'can',
#    'count',
#    'it',
#    'on',
#    'your',
#    'fingertips',
#    ',',
#    "'",
#    "'",
#    'said',
#    'veteran',
#    'Miami',
#    'Beach',
#    'political',
#    'Gerald',
#    'Schwartz.'],
#   'entities': [{'type': 'Loc', 'start': 14, 'end': 16},
#    {'type': 'Peop', 'start': 17, 'end': 19}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 0}],
#   'orig_id': 1871},
#  {'tokens': ['Not',
#    'content',
#    'with',
#    'that',
#    'major',
#    'error',
#    ',',
#    'the',
#    'Journal',
#    'editorial',
#    'illustrated',
#    'a',
#    'lack',
#    'of',
#    'understanding',
#    'of',
#    'the',
#    'overwhelming',
#    'evidence',
#    'in',
#    'the',
#    'Warren',
#    'Commission',
#    'Report',
#    'proving',
#    'that',
#    'Lee',
#    'Harvey',
#    'Oswald',
#    'was',
#    'the',
#    'lone',
#    'gunman',
#    'who',
#    'killed',
#    'President',
#    'Kennedy',
#    'and',
#    'who',
#    '45',
#    'minutes',
#    'later',
#    'killed',
#    'Dallas',
#    'Police',
#    'Officer',
#    'J.D.',
#    'Tippit.'],
#   'entities': [{'type': 'Org', 'start': 8, 'end': 9},
#    {'type': 'Other', 'start': 21, 'end': 24},
#    {'type': 'Peop', 'start': 26, 'end': 29},
#    {'type': 'Peop', 'start': 35, 'end': 37},
#    {'type': 'Peop', 'start': 43, 'end': 48}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 3},
#    {'type': 'Kill', 'head': 2, 'tail': 4}],
#   'orig_id': 5243},
#  {'tokens': ['Meanwhile',
#    ',',
#    'on',
#    'a',
#    'separate',
#    'occasion',
#    ',',
#    'Prince',
#    'Ranariddh',
#    ',',
#    'first',
#    'prime',
#    'of',
#    'Cambodia',
#    ',',
#    'reiterated',
#    'the',
#    'Phnom',
#    'Penh',
#    'government',
#    "'s",
#    'wish',
#    'to',
#    'open',
#    'a',
#    'Cambodian',
#    'Embassy',
#    'in',
#    'Jakarta',
#    'as',
#    'soon',
#    'as',
#    'possible',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 7, 'end': 9},
#    {'type': 'Loc', 'start': 13, 'end': 14},
#    {'type': 'Org', 'start': 17, 'end': 20},
#    {'type': 'Loc', 'start': 28, 'end': 29}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1},
#    {'type': 'Work_For', 'head': 0, 'tail': 2},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 1}],
#   'orig_id': 4111},
#  {'tokens': ['Church',
#    "'s",
#    'is',
#    'headquartered',
#    'in',
#    'San',
#    'Antonio',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 5, 'end': 7}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1}],
#   'orig_id': 1391},
#  {'tokens': ['He',
#    'graduated',
#    'from',
#    'high',
#    'school',
#    'from',
#    'Benton',
#    ',',
#    'Tenn.',
#    'and',
#    'from',
#    'Tennessee',
#    'Tech',
#    'in',
#    'Cookville',
#    ',',
#    'and',
#    'holds',
#    'a',
#    'doctorate',
#    'in',
#    'physics',
#    'from',
#    'Virginia',
#    'Tech',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 6, 'end': 7},
#    {'type': 'Loc', 'start': 8, 'end': 9},
#    {'type': 'Org', 'start': 11, 'end': 13},
#    {'type': 'Loc', 'start': 14, 'end': 15},
#    {'type': 'Org', 'start': 23, 'end': 25}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 3},
#    {'type': 'Located_In', 'head': 3, 'tail': 1}],
#   'orig_id': 862},
#  {'tokens': ['In',
#    '1893',
#    ',',
#    'comedian',
#    'Harold',
#    'Lloyd',
#    'was',
#    'born',
#    'in',
#    'Burchard',
#    ',',
#    'Neb',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 9, 'end': 12}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5265},
#  {'tokens': ['Sofia', 'BTA'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Org', 'start': 1, 'end': 2}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3233},
#  {'tokens': ['In',
#    '1752',
#    ',',
#    'flagmaker',
#    'Betsy',
#    'Ross',
#    'was',
#    'born',
#    'in',
#    'Philadelphia',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 9, 'end': 10}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5357},
#  {'tokens': ['GSA',
#    'Depot',
#    ',',
#    'Davisville',
#    ',',
#    'R.I.',
#    ';',
#    'and',
#    'Mineral',
#    'Wells',
#    ',',
#    'Texas',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 3, 'end': 4},
#    {'type': 'Loc', 'start': 5, 'end': 6},
#    {'type': 'Loc', 'start': 8, 'end': 10},
#    {'type': 'Loc', 'start': 11, 'end': 12}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1},
#    {'type': 'Located_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2},
#    {'type': 'Located_In', 'head': 3, 'tail': 4}],
#   'orig_id': 137},
#  {'tokens': ['King',
#    'rose',
#    'to',
#    'prominence',
#    'after',
#    'Mrs.',
#    'Parks',
#    "'",
#    'action',
#    'in',
#    'December',
#    '1955',
#    'in',
#    'Montgomery',
#    ',',
#    'Ala.',
#    ',',
#    'set',
#    'the',
#    'stage',
#    'for',
#    'a',
#    'boycott',
#    'and',
#    'subsequent',
#    'demonstrations',
#    'that',
#    'caught',
#    'the',
#    'nation',
#    'by',
#    'surprise',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 5, 'end': 7},
#    {'type': 'Other', 'start': 11, 'end': 12},
#    {'type': 'Loc', 'start': 13, 'end': 14},
#    {'type': 'Loc', 'start': 15, 'end': 16}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 3},
#    {'type': 'Live_In', 'head': 1, 'tail': 4},
#    {'type': 'Located_In', 'head': 3, 'tail': 4}],
#   'orig_id': 894},
#  {'tokens': ['Kennedy',
#    'had',
#    'just',
#    'won',
#    'California',
#    "'s",
#    'Democratic',
#    'presidential',
#    'primary',
#    'when',
#    'Sirhan',
#    'shot',
#    'him',
#    'in',
#    'Los',
#    'Angeles',
#    'on',
#    'June',
#    '5',
#    ',',
#    '1968',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 4, 'end': 5},
#    {'type': 'Peop', 'start': 10, 'end': 11},
#    {'type': 'Loc', 'start': 14, 'end': 16},
#    {'type': 'Other', 'start': 17, 'end': 18}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 0}],
#   'orig_id': 5145},
#  {'tokens': ['Dan',
#    'Quayle',
#    "'s",
#    'first',
#    'trip',
#    'out',
#    'of',
#    'the',
#    'country',
#    'as',
#    'vice',
#    'is',
#    'likely',
#    'to',
#    'be',
#    'to',
#    'Caracas',
#    ',',
#    'Venezuela',
#    ',',
#    'for',
#    'Carlos',
#    'Andres',
#    'Perez',
#    "'s",
#    'presidential',
#    'inauguration',
#    'on',
#    'Feb.',
#    '2',
#    ',',
#    'an',
#    'official',
#    'in',
#    'President-elect',
#    'Bush',
#    "'s",
#    'transition',
#    'said',
#    'Thursday',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 16, 'end': 17},
#    {'type': 'Loc', 'start': 18, 'end': 19},
#    {'type': 'Peop', 'start': 21, 'end': 24},
#    {'type': 'Other', 'start': 28, 'end': 31}],
#   'relations': [{'type': 'Located_In', 'head': 1, 'tail': 2},
#    {'type': 'Live_In', 'head': 3, 'tail': 1},
#    {'type': 'Live_In', 'head': 3, 'tail': 2}],
#   'orig_id': 1006},
#  {'tokens': ['Rogers',
#    ',',
#    'a',
#    'native',
#    'of',
#    'Fort',
#    'Worth',
#    ',',
#    'Texas',
#    ',',
#    'has',
#    'a',
#    'dry',
#    'wit',
#    'and',
#    'so',
#    'much',
#    'of',
#    'the',
#    'American',
#    'southwest',
#    'in',
#    'his',
#    'manner',
#    'and',
#    'voice',
#    'that',
#    'he',
#    'spends',
#    'a',
#    'lot',
#    'of',
#    'time',
#    'denying',
#    'he',
#    "'s",
#    'related',
#    'to',
#    'the',
#    'famous',
#    'Oklahoma',
#    'cowboy',
#    'humorist',
#    'Will',
#    'Rogers',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 5, 'end': 9},
#    {'type': 'Loc', 'start': 40, 'end': 41},
#    {'type': 'Peop', 'start': 43, 'end': 45}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5281},
#  {'tokens': ['Sirhan',
#    'says',
#    'he',
#    'was',
#    'the',
#    'lone',
#    'assassin',
#    'but',
#    'can',
#    "'t",
#    'remember',
#    'shooting',
#    'Kennedy',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 12, 'end': 13}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 1}],
#   'orig_id': 5016},
#  {'tokens': ['The',
#    'registrar',
#    'of',
#    'the',
#    'University',
#    'of',
#    'Nigeria',
#    "'s",
#    'Nsukka',
#    'campus',
#    ',',
#    'U.',
#    'Umeh',
#    ',',
#    'said',
#    'he',
#    'had',
#    'closed',
#    'the',
#    'university',
#    'on',
#    'the',
#    'advice',
#    'of',
#    'the',
#    'government',
#    '.'],
#   'entities': [{'type': 'Other', 'start': 4, 'end': 5},
#    {'type': 'Loc', 'start': 6, 'end': 7},
#    {'type': 'Loc', 'start': 8, 'end': 9},
#    {'type': 'Other', 'start': 11, 'end': 13}],
#   'relations': [{'type': 'Located_In', 'head': 2, 'tail': 1}],
#   'orig_id': 5514},
#  {'tokens': ['In',
#    'Colorado',
#    ',',
#    '13',
#    'inches',
#    'of',
#    'snow',
#    'in',
#    'Denver',
#    'Wednesday',
#    'prompted',
#    'officials',
#    'to',
#    'close',
#    'Interstate',
#    '270',
#    'temporarily',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Other', 'start': 3, 'end': 5},
#    {'type': 'Loc', 'start': 8, 'end': 9}],
#   'relations': [{'type': 'Located_In', 'head': 2, 'tail': 0}],
#   'orig_id': 373},
#  {'tokens': ['Edward',
#    'Marks',
#    ',',
#    'an',
#    'official',
#    'with',
#    'the',
#    'Montgomery',
#    'County',
#    'Democratic',
#    'Party',
#    ',',
#    'argued',
#    'that',
#    'if',
#    'Ms.',
#    'Toth',
#    'is',
#    'not',
#    'interested',
#    'in',
#    'the',
#    'job',
#    ',',
#    '`',
#    '`',
#    'she',
#    'should',
#    'get',
#    'out.',
#    '..',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Org', 'start': 7, 'end': 11},
#    {'type': 'Peop', 'start': 15, 'end': 17}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 494},
#  {'tokens': ['Moscow', 'IZVESTIYA'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Org', 'start': 1, 'end': 2}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3930},
#  {'tokens': ['He',
#    'said',
#    'he',
#    'only',
#    'learned',
#    'his',
#    'father',
#    'was',
#    'a',
#    'war-stress',
#    'patient',
#    'at',
#    'St.',
#    'Nicholas',
#    'Hospital',
#    'in',
#    'Gosforth',
#    'in',
#    'northeast',
#    'England',
#    'after',
#    'he',
#    'died',
#    'two',
#    'years',
#    'ago',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 12, 'end': 15},
#    {'type': 'Loc', 'start': 16, 'end': 17},
#    {'type': 'Loc', 'start': 19, 'end': 20},
#    {'type': 'Other', 'start': 23, 'end': 25}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 72},
#  {'tokens': ['ROYAL', 'OAK', ',', 'Mich', '.'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 3, 'end': 5}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1}],
#   'orig_id': 183},
#  {'tokens': ['The',
#    'session',
#    'was',
#    'opened',
#    'by',
#    'Aleksandr',
#    'Kruhlow',
#    ',',
#    'a',
#    '72-year-old',
#    'deputy',
#    'from',
#    'Sevastopol',
#    ',',
#    'organizer',
#    'of',
#    'many',
#    'meetings',
#    'in',
#    'Nakhimov',
#    'Square',
#    ',',
#    'and',
#    'an',
#    'untiring',
#    'fighter',
#    'for',
#    'the',
#    'return',
#    'of',
#    'Sevastopol',
#    'and',
#    'the',
#    'Crimea',
#    'to',
#    'Russia',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 5, 'end': 7},
#    {'type': 'Loc', 'start': 12, 'end': 13},
#    {'type': 'Loc', 'start': 19, 'end': 21},
#    {'type': 'Loc', 'start': 30, 'end': 31},
#    {'type': 'Loc', 'start': 33, 'end': 34},
#    {'type': 'Loc', 'start': 35, 'end': 36}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 4463},
#  {'tokens': ['The',
#    'Coast',
#    'Guard',
#    'rescued',
#    'seven',
#    'people',
#    'from',
#    'a',
#    'sinking',
#    'shrimp',
#    'boat',
#    'near',
#    'the',
#    'Sabine',
#    'Pass',
#    'station',
#    ',',
#    'said',
#    'station',
#    'chief',
#    'Kenneth',
#    'Compton.'],
#   'entities': [{'type': 'Org', 'start': 1, 'end': 3},
#    {'type': 'Loc', 'start': 13, 'end': 16},
#    {'type': 'Peop', 'start': 20, 'end': 22}],
#   'relations': [{'type': 'Work_For', 'head': 2, 'tail': 0}],
#   'orig_id': 1952},
#  {'tokens': ['Most',
#    'of',
#    'the',
#    'work',
#    'conducted',
#    'by',
#    'the',
#    'Warren',
#    'Commission',
#    ',',
#    'which',
#    'concluded',
#    'that',
#    'Lee',
#    'Harvey',
#    'Oswald',
#    'acted',
#    'alone',
#    'in',
#    'the',
#    'Kennedy',
#    'slaying',
#    ',',
#    'has',
#    'been',
#    'opened',
#    'to',
#    'the',
#    'public',
#    ',',
#    'a',
#    'move',
#    'that',
#    'has',
#    'helped',
#    'researchers',
#    'evaluate',
#    '_',
#    'and',
#    'in',
#    'many',
#    'cases',
#    'strongly',
#    'criticize',
#    '_',
#    'that',
#    'investigation',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 7, 'end': 9},
#    {'type': 'Peop', 'start': 13, 'end': 16},
#    {'type': 'Peop', 'start': 20, 'end': 21}],
#   'relations': [{'type': 'Kill', 'head': 1, 'tail': 2}],
#   'orig_id': 5052},
#  {'tokens': ['In',
#    '1898',
#    ',',
#    'composer',
#    'George',
#    'Gershwin',
#    'was',
#    'born',
#    'in',
#    'New',
#    'York',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 6},
#    {'type': 'Loc', 'start': 9, 'end': 11}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5295},
#  {'tokens': ['"',
#    'U.S.',
#    'decision-makers',
#    'should',
#    'understand',
#    'that',
#    'the',
#    'signals',
#    'they',
#    'send',
#    'today',
#    'will',
#    'have',
#    'major',
#    'ramifications',
#    'for',
#    'the',
#    'Israeli',
#    'approach',
#    'to',
#    'the',
#    'Arrow',
#    'program',
#    ',',
#    '"',
#    'says',
#    'Marvin',
#    'Feuerwerger',
#    'in',
#    'a',
#    '1991',
#    'study',
#    'for',
#    'the',
#    'Washington',
#    'Institute',
#    'for',
#    'Near',
#    'East',
#    'Policy',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Peop', 'start': 26, 'end': 28},
#    {'type': 'Other', 'start': 30, 'end': 31},
#    {'type': 'Org', 'start': 34, 'end': 40}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 3}],
#   'orig_id': 3514},
#  {'tokens': ['He',
#    'disclosed',
#    'that',
#    'engineers',
#    'at',
#    'the',
#    'St.',
#    'Petersburg',
#    'branch',
#    'of',
#    'the',
#    'Atomenergoproekt',
#    'institute',
#    'were',
#    'completing',
#    'work',
#    'on',
#    'the',
#    'design',
#    'of',
#    'a',
#    'new',
#    'NP-500',
#    'reactor',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 6, 'end': 8},
#    {'type': 'Org', 'start': 11, 'end': 13}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3881},
#  {'tokens': ['But',
#    'four',
#    'years',
#    'later',
#    ',',
#    'Wright',
#    'said',
#    'he',
#    'would',
#    'vote',
#    'against',
#    'Barry',
#    'Goldwater',
#    'because',
#    'he',
#    'felt',
#    'the',
#    'Arizona',
#    'senator',
#    'supported',
#    'a',
#    '`',
#    '`',
#    'slowdown',
#    'on',
#    'civil',
#    'rights',
#    "'",
#    "'",
#    'and',
#    'would',
#    'take',
#    'a',
#    '`',
#    '`',
#    'harder',
#    ',',
#    'more',
#    'dangerous',
#    'line',
#    'on',
#    'foreign',
#    'relations.',
#    "'",
#    "'"],
#   'entities': [{'type': 'Other', 'start': 1, 'end': 3},
#    {'type': 'Peop', 'start': 5, 'end': 6},
#    {'type': 'Peop', 'start': 11, 'end': 13},
#    {'type': 'Loc', 'start': 17, 'end': 18}],
#   'relations': [{'type': 'Live_In', 'head': 2, 'tail': 3}],
#   'orig_id': 68},
#  {'tokens': ['DIMA',
#    "'s",
#    'technical',
#    'manager',
#    ',',
#    'engineer',
#    'Jose',
#    'Tulio',
#    'Gomez',
#    ',',
#    'said',
#    'that',
#    'in',
#    'addition',
#    'to',
#    'industrial',
#    'wastes',
#    ',',
#    'the',
#    'rivers',
#    'are',
#    'also',
#    'contaminated',
#    'by',
#    'human',
#    'waste',
#    ',',
#    'and',
#    'diesel',
#    'and',
#    'petroleum',
#    'residues',
#    'discarded',
#    'by',
#    'a',
#    'number',
#    'of',
#    'factories',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 6, 'end': 9}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 0}],
#   'orig_id': 3061},
#  {'tokens': ['Besides',
#    ',',
#    'the',
#    'captain',
#    'said',
#    ',',
#    'the',
#    'black-eyed',
#    'peas',
#    'matter',
#    ',',
#    'as',
#    'it',
#    'was',
#    'termed',
#    'in',
#    'the',
#    'papers',
#    ',',
#    'was',
#    'of',
#    'interest',
#    'to',
#    'the',
#    'president',
#    'of',
#    'the',
#    'black-eyed',
#    'pea',
#    'industry',
#    'as',
#    'well',
#    'as',
#    'to',
#    'Gen.',
#    'William',
#    'C.',
#    'Westmoreland',
#    ',',
#    'the',
#    'commander',
#    'of',
#    'U.S.',
#    'forces',
#    'in',
#    'Vietnam',
#    'and',
#    'a',
#    'South',
#    'Carolina',
#    'native',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 34, 'end': 38},
#    {'type': 'Loc', 'start': 42, 'end': 43},
#    {'type': 'Loc', 'start': 45, 'end': 46},
#    {'type': 'Loc', 'start': 48, 'end': 50}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 3}],
#   'orig_id': 5279},
#  {'tokens': ['`',
#    '`',
#    'Please',
#    'don',
#    "'t",
#    'execute',
#    'him',
#    ',',
#    'please',
#    ',',
#    "'",
#    "'",
#    'said',
#    'Mrs.',
#    'Cicippio',
#    ',',
#    'who',
#    'works',
#    'at',
#    'the',
#    'American',
#    'Embassy',
#    'in',
#    'east',
#    'Beirut.'],
#   'entities': [{'type': 'Peop', 'start': 13, 'end': 15},
#    {'type': 'Loc', 'start': 20, 'end': 22},
#    {'type': 'Loc', 'start': 24, 'end': 25}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 2},
#    {'type': 'Located_In', 'head': 1, 'tail': 2}],
#   'orig_id': 2320},
#  {'tokens': ['Many',
#    'of',
#    'the',
#    'first',
#    'visitors',
#    'to',
#    'a',
#    'new',
#    'museum',
#    'at',
#    'the',
#    'former',
#    'Texas',
#    'School',
#    'Book',
#    'Depository',
#    'went',
#    'directly',
#    'to',
#    'the',
#    'sixth-floor',
#    'spot',
#    'where',
#    'Lee',
#    'Harvey',
#    'Oswald',
#    'allegedly',
#    'fired',
#    'the',
#    'shots',
#    'that',
#    'killed',
#    'President',
#    'Kennedy',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 12, 'end': 16},
#    {'type': 'Peop', 'start': 23, 'end': 26},
#    {'type': 'Peop', 'start': 32, 'end': 34}],
#   'relations': [{'type': 'Kill', 'head': 1, 'tail': 2}],
#   'orig_id': 5079},
#  {'tokens': ['BELGRADE', ',', 'Yugoslavia', '(', 'AP', ')'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 2, 'end': 3},
#    {'type': 'Org', 'start': 4, 'end': 5}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 0},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 1}],
#   'orig_id': 2571},
#  {'tokens': ['A',
#    'Placerville',
#    'jury',
#    'Wednesday',
#    'convicted',
#    'Highway',
#    '50',
#    'sniper',
#    'Kenneth',
#    'Earl',
#    'Millikan',
#    'of',
#    'killing',
#    'Bay',
#    'Area',
#    'Rapid',
#    'Transit',
#    'District',
#    'employee',
#    'Peter',
#    'J.',
#    'Martinelli',
#    ',',
#    'the',
#    'son-in-law',
#    'of',
#    'BART',
#    'Director',
#    'Nello',
#    'Bianco.',
#    ';'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Other', 'start': 3, 'end': 4},
#    {'type': 'Other', 'start': 5, 'end': 6},
#    {'type': 'Peop', 'start': 8, 'end': 11},
#    {'type': 'Org', 'start': 13, 'end': 18},
#    {'type': 'Peop', 'start': 19, 'end': 22},
#    {'type': 'Peop', 'start': 26, 'end': 30}],
#   'relations': [{'type': 'Kill', 'head': 3, 'tail': 5}],
#   'orig_id': 5221},
#  {'tokens': ['Mrs.',
#    'Vogt',
#    'was',
#    'born',
#    'in',
#    'Akron',
#    ',Ohio',
#    ',',
#    'when',
# ...
#   'orig_id': 2120},
#  {'tokens': ['Today',
#    "'s",
#    'highlight',
#    'in',
#    'history',
#    ':',
#    'In',
#    '1901',
#    ',',
#    'President',
#    'William',
#    'McKinley',
#    'was',
#    'shot',
#    'by',
#    'anarchist',
#    'Leon',
#    'Czolgosz',
#    'at',
#    'the',
#    'Pan-American',
#    'Exposition',
#    'in',
#    'Buffalo',
#    ',',
#    'N.Y.'],
#   'entities': [{'type': 'Peop', 'start': 9, 'end': 12},
#    {'type': 'Peop', 'start': 16, 'end': 18},
#    {'type': 'Other', 'start': 21, 'end': 22},
#    {'type': 'Loc', 'start': 23, 'end': 26}],
#   'relations': [{'type': 'Kill', 'head': 1, 'tail': 0}],
#   'orig_id': 5034},
#  {'tokens': ['Police',
#    'Major',
#    'Pramot',
#    'said',
#    'that',
#    'even',
#    'though',
#    'officials',
#    'managed',
#    'to',
#    'destroy',
#    'a',
#    'large',
#    'number',
#    'of',
#    'poppy',
#    'plants',
#    ',',
#    'he',
#    'ordered',
#    'Police',
#    'Colonel',
#    'Suraphong',
#    'Khemasingkhi',
#    ',',
#    'the',
#    'superintendent',
#    'of',
#    'BPP',
#    'Unit',
#    '24',
#    ',',
#    'to',
#    'mobilize',
#    'a',
#    'team',
#    'of',
#    'BPP',
#    'officials',
#    'and',
#    'asked',
#    'for',
#    'the',
#    'cooperation',
#    'of',
#    'the',
#    'units',
#    'concerned',
#    'to',
#    'destroy',
#    'the',
#    'rest',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 2, 'end': 3},
#    {'type': 'Peop', 'start': 22, 'end': 24},
#    {'type': 'Org', 'start': 28, 'end': 31}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 2}],
#   'orig_id': 3778},
#  {'tokens': ['(',
#    'Editorial',
#    'Report',
#    ')',
#    'The',
#    '11',
#    'April',
#    'Jakarta',
#    'BISNIS',
#    'INDONESIA',
#    'in',
#    'Indonesian',
#    'on',
#    'page',
#    '5',
#    'reported',
#    'that',
#    'the',
#    'recently',
#    'established',
#    'East',
#    'Asian',
#    'Growth',
#    'Area',
#    '(',
#    'EAGA',
#    ')',
#    'encompassing',
#    'the',
#    'eastern',
#    'region',
#    'of',
#    'Indonesia',
#    ',',
#    'the',
#    'Malaysian',
#    'states',
#    'of',
#    'Sabah',
#    'and',
#    'Sarawak',
#    ',',
#    'Brunei',
#    ',',
#    'and',
#    'the',
#    'Mindanao',
#    'islands',
#    'of',
#    'the',
#    'Philippines',
#    '-',
#    '-',
#    'is',
#    'expected',
#    'to',
#    'increase',
#    'Indonesia',
#    "'s",
#    'exports',
#    'from',
#    'its',
#    'eastern',
#    'region.'],
#   'entities': [{'type': 'Other', 'start': 5, 'end': 7},
#    {'type': 'Loc', 'start': 7, 'end': 8},
#    {'type': 'Org', 'start': 8, 'end': 10},
#    {'type': 'Loc', 'start': 20, 'end': 24},
#    {'type': 'Loc', 'start': 25, 'end': 26},
#    {'type': 'Loc', 'start': 32, 'end': 33},
#    {'type': 'Loc', 'start': 38, 'end': 39},
#    {'type': 'Loc', 'start': 40, 'end': 41},
#    {'type': 'Loc', 'start': 42, 'end': 43},
#    {'type': 'Loc', 'start': 46, 'end': 48},
#    {'type': 'Loc', 'start': 49, 'end': 51},
#    {'type': 'Loc', 'start': 57, 'end': 58}],
#   'relations': [{'type': 'OrgBased_In', 'head': 2, 'tail': 5},
#    {'type': 'OrgBased_In', 'head': 2, 'tail': 11},
#    {'type': 'Located_In', 'head': 9, 'tail': 10}],
#   'orig_id': 4326},
#  {'tokens': ['In',
#    '1809',
#    ',',
#    'author',
#    'Edgar',
#    'Allan',
#    'Poe',
#    'was',
#    'born',
#    'in',
#    'Boston',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 4, 'end': 7},
#    {'type': 'Loc', 'start': 10, 'end': 11}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1}],
#   'orig_id': 5359},
#  {'tokens': ['PA2105201294',
#    'Panama',
#    'City',
#    'ACAN',
#    'in',
#    'Spanish',
#    '1742',
#    'GMT',
#    '21',
#    'May',
#    '94'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 3},
#    {'type': 'Org', 'start': 3, 'end': 4},
#    {'type': 'Other', 'start': 6, 'end': 8},
#    {'type': 'Other', 'start': 8, 'end': 11}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 4241},
#  {'tokens': ['Washington',
#    ':',
#    'About',
#    '110',
#    'firefighters',
#    'cut',
#    'a',
#    'containment',
#    'line',
#    'most',
#    'of',
#    'the',
#    'way',
#    'around',
#    'an',
#    '850-acre',
#    'forest',
#    'fire',
#    'in',
#    'the',
#    'Pasayten',
#    'Wilderness',
#    'near',
#    'the',
#    'Canadian',
#    'border',
#    'Tuesday.'],
#   'entities': [{'type': 'Loc', 'start': 0, 'end': 1},
#    {'type': 'Loc', 'start': 20, 'end': 22}],
#   'relations': [{'type': 'Located_In', 'head': 1, 'tail': 0}],
#   'orig_id': 2161},
#  {'tokens': ['Rep.',
#    'Edward',
#    'Roybal',
#    ',',
#    'D-Calif.',
#    ',',
#    'chairman',
#    'of',
#    'the',
#    'House',
#    'Appropriations',
#    'treasury',
#    'and',
#    'postal',
#    'subcommittee',
#    ',',
#    'which',
#    'authored',
#    'the',
#    'House-passed',
#    'spending',
#    'bill',
#    ',',
#    'said',
#    'Mrs.',
#    'Quayle',
#    'invited',
#    'them',
#    'to',
#    'visit',
#    'the',
#    'mansion',
#    'and',
#    'examine',
#    'the',
#    'needed',
#    'work.'],
#   'entities': [{'type': 'Peop', 'start': 1, 'end': 3},
#    {'type': 'Org', 'start': 9, 'end': 15},
#    {'type': 'Peop', 'start': 24, 'end': 26}],
#   'relations': [{'type': 'Work_For', 'head': 0, 'tail': 1}],
#   'orig_id': 1546},
#  {'tokens': ['SOVETSKAYA',
#    'ROSSIA',
#    '(',
#    'opposition',
#    'newspaper',
#    ')',
#    'gives',
#    'a',
#    'digest',
#    'of',
#    'the',
#    'report',
#    'on',
#    'social',
#    'and',
#    'economic',
#    'situation',
#    'in',
#    'Russia',
#    'compiled',
#    'by',
#    'the',
#    'Russian',
#    'Statistics',
#    'Committee',
#    ',',
#    'which',
#    'was',
#    'circulated',
#    'in',
#    'the',
#    'Kremlin',
#    'among',
#    'participants',
#    'in',
#    'the',
#    'enlarged',
#    'meeting',
#    'of',
#    'the',
#    'government',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 18, 'end': 19},
#    {'type': 'Org', 'start': 22, 'end': 25},
#    {'type': 'Loc', 'start': 31, 'end': 32}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 2958},
#  {'tokens': ['Historic',
#    'Movie',
#    'House',
#    'May',
#    'Close',
#    ':',
#    'The',
#    'Texas',
#    'Theater',
#    ',',
#    'the',
#    'Dallas',
#    'movie',
#    'house',
#    'where',
#    'Lee',
#    'Harvey',
#    'Oswald',
#    'was',
#    'arrested',
#    'after',
#    'the',
#    'assassination',
#    'of',
#    'President',
#    'John',
#    'F.',
#    'Kennedy',
#    ',',
#    'may',
#    'be',
#    'closing',
#    'soon',
#    '.'],
#   'entities': [{'type': 'Other', 'start': 0, 'end': 4},
#    {'type': 'Loc', 'start': 7, 'end': 9},
#    {'type': 'Loc', 'start': 11, 'end': 12},
#    {'type': 'Peop', 'start': 15, 'end': 18},
#    {'type': 'Peop', 'start': 24, 'end': 28}],
#   'relations': [{'type': 'Kill', 'head': 3, 'tail': 4}],
#   'orig_id': 5209},
#  {'tokens': ['In',
#    'Washington',
#    ',',
#    'U.S.',
#    'strategists',
#    'upgraded',
#    'the',
#    'missile',
#    'threat',
#    'from',
#    'Pyongyang',
#    'from',
#    'potential',
#    'to',
#    'real',
#    'and',
#    'decided',
#    'that',
#    'the',
#    'communist',
#    'country',
#    'required',
#    'high-level',
#    'attention',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Loc', 'start': 3, 'end': 4},
#    {'type': 'Loc', 'start': 10, 'end': 11},
#    {'type': 'Org', 'start': 19, 'end': 20}],
#   'relations': [{'type': 'Located_In', 'head': 0, 'tail': 1}],
#   'orig_id': 3402},
#  {'tokens': ['LD0706183794',
#    'Riga',
#    'Radio',
#    'Riga',
#    'Network',
#    'in',
#    'Latvian',
#    '1700',
#    'GMT',
#    '7',
#    'Jun',
#    '94'],
#   'entities': [{'type': 'Loc', 'start': 1, 'end': 2},
#    {'type': 'Org', 'start': 2, 'end': 5},
#    {'type': 'Other', 'start': 7, 'end': 9},
#    {'type': 'Other', 'start': 9, 'end': 12}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 4203},
#  {'tokens': ['Lehi',
#    ',',
#    'also',
#    'known',
#    'as',
#    'the',
#    'Stern',
#    'Gang',
#    ',',
#    'assassinated',
#    'the',
#    'British',
#    'colonial',
#    'minister',
#    ',',
#    'Lord',
#    'Moyne',
#    ',',
#    'and',
#    'the',
#    'Swedish',
#    'U.N.',
#    'mediator',
#    ',',
#    'Count',
#    'Folke',
#    'Bernadotte.',
#    ';'],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 6, 'end': 8},
#    {'type': 'Peop', 'start': 15, 'end': 17},
#    {'type': 'Org', 'start': 21, 'end': 22},
#    {'type': 'Peop', 'start': 25, 'end': 27}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 2},
#    {'type': 'Kill', 'head': 0, 'tail': 4},
#    {'type': 'Kill', 'head': 1, 'tail': 2},
#    {'type': 'Kill', 'head': 1, 'tail': 4}],
#   'orig_id': 5220},
#  {'tokens': ['of',
#    'Shinseito',
#    '(',
#    'Japan',
#    'Renewal',
#    'Party',
#    ')',
#    ',',
#    'by',
#    'Takeshi',
#    'Sasaki',
#    ',',
#    'Tokyo',
#    'University',
#    'professor',
#    ',',
#    'on',
#    '13',
#    'February',
#    ',',
#    'moderated',
#    'by',
#    'Shoichi',
#    'Oikawa',
#    ',',
#    'YOMIURI',
#    'SHIMBUN',
#    'political',
#    'editor',
#    ';',
#    'place',
#    'not',
#    'given',
#    ';',
#    'first',
#    'paragraph',
#    'is',
#    'YOMIURI',
#    'SHIMBUN',
#    'introduction',
#    ')',
#    '(',
#    'Excerpts',
#    ')',
#    'After',
#    'the',
#    'passage',
#    'of',
#    'the',
#    'political',
#    'reform',
#    'laws',
#    ',',
#    'as',
#    'vigorous',
#    'moves',
#    'toward',
#    'the',
#    'realignment',
#    'of',
#    'the',
#    'political',
#    'world',
#    'become',
#    'apparent',
#    ',',
#    'YOMIURI',
#    'SHIMBUN',
#    'invited',
#    'Ichiro',
#    'Ozawa',
#    ',',
#    'secretary',
#    'of',
#    'Shinseito',
#    ',',
#    'on',
#    '13',
#    'February',
#    'to',
#    'talk',
#    'for',
#    'about',
#    'two',
#    'hours',
#    'on',
#    'the',
#    'possible',
#    'course',
#    'of',
#    'political',
#    'realignment',
#    ',',
#    'foreign',
#    'policy',
#    'and',
#    'security',
#    ',',
#    'international',
#    'contribution',
#    ',',
#    'and',
#    'his',
#    'assessment',
#    'of',
#    'postwar',
#    'politics',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 1, 'end': 2},
#    {'type': 'Org', 'start': 3, 'end': 6},
#    {'type': 'Peop', 'start': 9, 'end': 11},
#    {'type': 'Org', 'start': 12, 'end': 14},
#    {'type': 'Other', 'start': 17, 'end': 19},
#    {'type': 'Peop', 'start': 22, 'end': 24},
#    {'type': 'Org', 'start': 25, 'end': 27},
#    {'type': 'Org', 'start': 37, 'end': 39},
#    {'type': 'Org', 'start': 66, 'end': 68},
#    {'type': 'Peop', 'start': 69, 'end': 71},
#    {'type': 'Org', 'start': 74, 'end': 75},
#    {'type': 'Other', 'start': 77, 'end': 79}],
#   'relations': [{'type': 'Work_For', 'head': 2, 'tail': 3},
#    {'type': 'Work_For', 'head': 5, 'tail': 6},
#    {'type': 'Work_For', 'head': 5, 'tail': 7},
#    {'type': 'Work_For', 'head': 5, 'tail': 8},
#    {'type': 'Work_For', 'head': 9, 'tail': 0},
#    {'type': 'Work_For', 'head': 9, 'tail': 10}],
#   'orig_id': 3153},
#  {'tokens': ['In',
#    '1822',
#    ',',
#    'the',
#    '18th',
#    'president',
#    'of',
#    'the',
#    'United',
#    'States',
#    ',',
#    'Ulysses',
#    'S.',
#    'Grant',
#    ',',
#    'was',
#    'born',
#    'in',
#    'Point',
#    'Pleasant',
#    ',',
#    'Ohio',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 8, 'end': 10},
#    {'type': 'Peop', 'start': 11, 'end': 14},
#    {'type': 'Loc', 'start': 18, 'end': 22}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 2}],
#   'orig_id': 5366},
#  {'tokens': ['Wang',
#    'Shaohua',
#    ',',
#    'an',
#    'official',
#    'with',
#    'China',
#    "'s",
#    'consulate',
#    'in',
#    'San',
#    'Francisco',
#    ',',
#    'said',
#    'those',
#    'who',
#    'fled',
#    '`',
#    '`',
#    'were',
#    'instigated',
#    'by',
#    'people',
#    'with',
#    'motives',
#    'to',
#    'bring',
#    'damage',
#    'to',
#    'China.',
#    "'",
#    "'"],
#   'entities': [{'type': 'Peop', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 6, 'end': 7},
#    {'type': 'Loc', 'start': 10, 'end': 12},
#    {'type': 'Loc', 'start': 29, 'end': 30}],
#   'relations': [{'type': 'Live_In', 'head': 0, 'tail': 2}],
#   'orig_id': 1752},
#  {'tokens': ['Her',
#    'husband',
#    "'s",
#    'assassin',
#    ',',
#    'Mark',
#    'David',
#    'Chapman',
#    ',',
#    'said',
#    'he',
#    'had',
#    'decided',
#    'to',
#    'kill',
#    'John',
#    'Lennon',
#    'in',
#    '1980',
#    'after',
#    'reading',
#    'an',
#    'article',
#    'about',
#    'the',
#    'former',
#    'Beatle',
#    'in',
#    'a',
#    'magazine',
#    ',',
#    'Ono',
#    'said',
#    '.'],
#   'entities': [{'type': 'Peop', 'start': 5, 'end': 8},
#    {'type': 'Peop', 'start': 15, 'end': 17},
#    {'type': 'Other', 'start': 26, 'end': 27},
#    {'type': 'Peop', 'start': 31, 'end': 32}],
#   'relations': [{'type': 'Kill', 'head': 0, 'tail': 1}],
#   'orig_id': 5046},
#  {'tokens': ['Officials',
#    ',',
#    'Newspapers',
#    'Greet',
#    'End',
#    'of',
#    'SRV',
#    'Embargo',
#    'Editorial',
#    'Hails',
#    'Embargo',
#    'End',
#    'BK0502093694',
#    'Bangkok',
#    'THE',
#    'NATION',
#    'in',
#    'English',
#    '5',
#    'Feb',
#    '94',
#    'p',
#    'A6'],
#   'entities': [{'type': 'Loc', 'start': 13, 'end': 14},
#    {'type': 'Org', 'start': 14, 'end': 16},
#    {'type': 'Other', 'start': 18, 'end': 21}],
#   'relations': [{'type': 'OrgBased_In', 'head': 1, 'tail': 0}],
#   'orig_id': 3108},
#  {'tokens': ['An-a-one',
#    ',',
#    'an-a-two',
#    ',',
#    'an-a-three',
#    'billion',
#    ')',
#    'Taxpayers',
#    'will',
#    'be',
#    'pleased',
#    'to',
#    'learn',
#    'that',
#    'a',
#    'federal',
#    'grant',
#    'for',
#    'Lawrence',
#    'Welk',
#    "'s",
#    'North',
#    'Dakota',
#    'birthplace',
#    'has',
#    'finally',
#    'been',
#    'buried',
#    ',',
#    'nine',
#    'months',
#    'after',
#    'an',
#    'embarrassed',
#    'Congress',
#    'voted',
#    'to',
#    'kill',
#    'it',
#    '.'],
#   'entities': [{'type': 'Other', 'start': 0, 'end': 1},
#    {'type': 'Peop', 'start': 18, 'end': 20},
#    {'type': 'Loc', 'start': 21, 'end': 23},
#    {'type': 'Org', 'start': 34, 'end': 35}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 2}],
#   'orig_id': 5423},
#  {'tokens': ['Another',
#    'GE',
#    'employee',
#    ',',
#    'attorney',
#    'Robert',
#    'C.',
#    'Anderson',
#    ',',
#    'said',
#    'in',
#    'a',
#    'letter',
#    'last',
#    'year',
#    'that',
#    'test',
#    'records',
#    'may',
#    'have',
#    'been',
#    'falsified',
#    'for',
#    'valves',
#    'used',
#    'on',
#    'the',
#    'FA-18',
#    'in',
#    '1984-87',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 1, 'end': 2},
#    {'type': 'Peop', 'start': 5, 'end': 8}],
#   'relations': [{'type': 'Work_For', 'head': 1, 'tail': 0}],
#   'orig_id': 1269},
#  {'tokens': ['(',
#    'Text',
#    ')',
#    'Following',
#    'the',
#    'conclusion',
#    'of',
#    'the',
#    'Geneva',
#    'negotiations',
#    'today',
#    ',',
#    'Ejup',
#    'Ganic',
#    ',',
#    'head',
#    'of',
#    'the',
#    'Bosnia-Herzegovina',
#    'delegation',
#    'and',
#    'vice',
#    'of',
#    'the',
#    'Federation',
#    'of',
#    'Bosnia-Herzegovina',
#    ',',
#    'made',
#    'the',
#    'following',
#    'statement',
#    'for',
#    'Bosnia-Herzegovina',
#    'Radio',
#    'and',
#    'TV',
#    ':',
#    '(',
#    'Begin',
#    'Ganic',
#    'recording',
#    ')',
#    'The',
#    'delegation',
#    'acted',
#    'in',
#    'accordance',
#    'with',
#    'the',
#    'Assembly',
#    'guidelines',
#    '.'],
#   'entities': [{'type': 'Loc', 'start': 8, 'end': 9},
#    {'type': 'Peop', 'start': 12, 'end': 14},
#    {'type': 'Loc', 'start': 24, 'end': 27},
#    {'type': 'Org', 'start': 33, 'end': 37}],
#   'relations': [{'type': 'Live_In', 'head': 1, 'tail': 2},
#    {'type': 'OrgBased_In', 'head': 3, 'tail': 2}],
#   'orig_id': 4136},
#  {'tokens': ['Eaglebrook',
#    'East',
#    'opened',
#    'in',
#    'Middletown',
#    'in',
#    'April',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 0, 'end': 2},
#    {'type': 'Loc', 'start': 4, 'end': 5}],
#   'relations': [{'type': 'OrgBased_In', 'head': 0, 'tail': 1}],
#   'orig_id': 1452},
#  {'tokens': ['Scattered',
#    'among',
#    'reams',
#    'of',
#    'FBI',
#    'and',
#    'Secret',
#    'Service',
#    'reports',
#    'are',
#    'fragments',
#    'of',
#    'the',
#    'lonely',
#    'life',
#    'of',
#    'Oswald',
#    ',',
#    'a',
#    'Marxist',
#    'who',
#    'lived',
#    'in',
#    'obscurity',
#    'and',
#    'died',
#    'in',
#    'infamy',
#    'and',
#    'who',
#    'the',
#    'Warren',
#    'Commission',
#    'concluded',
#    'was',
#    'acting',
#    'alone',
#    'when',
#    'he',
#    'killed',
#    'Kennedy',
#    '.'],
#   'entities': [{'type': 'Org', 'start': 4, 'end': 5},
#    {'type': 'Org', 'start': 6, 'end': 8},
#    {'type': 'Peop', 'start': 16, 'end': 17},
#    {'type': 'Org', 'start': 31, 'end': 33},
#    {'type': 'Peop', 'start': 40, 'end': 41}],
#   'relations': [{'type': 'Kill', 'head': 2, 'tail': 4}],
#   'orig_id': 5058}]

# %%
convert_tacred_to_conll04(tacred_train_examples[0])
# Out:
# {'tokens': ['Tom',
#   'Thabane',
#   'resigned',
#   'in',
#   'October',
#   'last',
#   'year',
#   'to',
#   'form',
#   'the',
#   'All',
#   'Basotho',
#   'Convention',
#   '(',
#   'ABC',
#   ')',
#   ',',
#   'crossing',
#   'the',
#   'floor',
#   'with',
#   '17',
#   'members',
#   'of',
#   'parliament',
#   ',',
#   'causing',
#   'constitutional',
#   'monarch',
#   'King',
#   'Letsie',
#   'III',
#   'to',
#   'dissolve',
#   'parliament',
#   'and',
#   'call',
#   'the',
#   'snap',
#   'election',
#   '.'],
#  'entities': [{'type': 'ORGANIZATION', 'start': 10, 'end': 12},
#   {'type': 'PERSON', 'start': 0, 'end': 1}],
#  'relations': [{'type': 'org:founded_by', 'head': 0, 'tail': 1}],
#  'orig_id': '61b3a5c8c9a882dcfcd2'}

# %%
tacred_train_examples = read_json(tacred_train_path)
tacred_dev_examples = read_json(tacred_dev_path)
tacred_test_examples = read_json(tacred_test_path)
tacred_examples = tacred_train_examples + tacred_dev_examples + tacred_test_examples

# %%
print('Loaded %s examples' % len(tacred_examples))
# Out:
# Loaded 106264 examples

# %%
tacred_examples[0]
# Out:
# {'id': '61b3a5c8c9a882dcfcd2',
#  'docid': 'AFP_ENG_20070218.0019.LDC2009T13',
#  'relation': 'org:founded_by',
#  'token': ['Tom',
#   'Thabane',
#   'resigned',
#   'in',
#   'October',
#   'last',
#   'year',
#   'to',
#   'form',
#   'the',
#   'All',
#   'Basotho',
#   'Convention',
#   '-LRB-',
#   'ABC',
#   '-RRB-',
#   ',',
#   'crossing',
#   'the',
#   'floor',
#   'with',
#   '17',
#   'members',
#   'of',
#   'parliament',
#   ',',
#   'causing',
#   'constitutional',
#   'monarch',
#   'King',
#   'Letsie',
#   'III',
#   'to',
#   'dissolve',
#   'parliament',
#   'and',
#   'call',
#   'the',
#   'snap',
#   'election',
#   '.'],
#  'subj_start': 10,
#  'subj_end': 12,
#  'obj_start': 0,
#  'obj_end': 1,
#  'subj_type': 'ORGANIZATION',
#  'obj_type': 'PERSON',
#  'stanford_pos': ['NNP',
#   'NNP',
#   'VBD',
#   'IN',
#   'NNP',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'DT',
#   'NNP',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   ',',
#   'VBG',
#   'JJ',
#   'NN',
#   'NNP',
#   'NNP',
#   'NNP',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   '.'],
#  'stanford_ner': ['PERSON',
#   'PERSON',
#   'O',
#   'O',
#   'DATE',
#   'DATE',
#   'DATE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'ORGANIZATION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'NUMBER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'PERSON',
#   'PERSON',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  'stanford_head': [2,
#   3,
#   0,
#   5,
#   3,
#   7,
#   3,
#   9,
#   3,
#   13,
#   13,
#   13,
#   9,
#   15,
#   13,
#   15,
#   3,
#   3,
#   20,
#   18,
#   23,
#   23,
#   18,
#   25,
#   23,
#   3,
#   3,
#   32,
#   32,
#   32,
#   32,
#   27,
#   34,
#   27,
#   34,
#   34,
#   34,
#   40,
#   40,
#   37,
#   3],
#  'stanford_deprel': ['compound',
#   'nsubj',
#   'ROOT',
#   'case',
#   'nmod',
#   'amod',
#   'nmod:tmod',
#   'mark',
#   'xcomp',
#   'det',
#   'compound',
#   'compound',
#   'dobj',
#   'punct',
#   'appos',
#   'punct',
#   'punct',
#   'xcomp',
#   'det',
#   'dobj',
#   'case',
#   'nummod',
#   'nmod',
#   'case',
#   'nmod',
#   'punct',
#   'xcomp',
#   'amod',
#   'compound',
#   'compound',
#   'compound',
#   'dobj',
#   'mark',
#   'xcomp',
#   'dobj',
#   'cc',
#   'conj',
#   'det',
#   'compound',
#   'dobj',
#   'punct']}

# %%
entity_types = set()
relation_types = set()
for example in tacred_examples:
    relation_types.add(example['relation'])
    entity_types.add(example['subj_type'])
    entity_types.add(example['obj_type'])
print(entity_types)
print(relation_types)
# Out:
# {'MISC', 'RELIGION', 'ORGANIZATION', 'LOCATION', 'DURATION', 'COUNTRY', 'NATIONALITY', 'CAUSE_OF_DEATH', 'IDEOLOGY', 'URL', 'STATE_OR_PROVINCE', 'NUMBER', 'CRIMINAL_CHARGE', 'TITLE', 'PERSON', 'DATE', 'CITY'}
# {'org:city_of_headquarters', 'per:spouse', 'per:cities_of_residence', 'per:city_of_death', 'org:country_of_headquarters', 'per:country_of_birth', 'per:siblings', 'org:shareholders', 'org:member_of', 'org:dissolved', 'per:schools_attended', 'org:political/religious_affiliation', 'per:city_of_birth', 'per:children', 'org:top_members/employees', 'per:stateorprovince_of_birth', 'per:stateorprovince_of_death', 'org:number_of_employees/members', 'per:countries_of_residence', 'org:founded', 'per:country_of_death', 'per:title', 'org:stateorprovince_of_headquarters', 'per:religion', 'org:founded_by', 'per:age', 'no_relation', 'per:stateorprovinces_of_residence', 'org:website', 'per:employee_of', 'org:parents', 'per:parents', 'org:alternate_names', 'org:subsidiaries', 'per:alternate_names', 'per:cause_of_death', 'per:date_of_death', 'org:members', 'per:date_of_birth', 'per:charges', 'per:origin', 'per:other_family'}

# %%
entities={
             "entities": {
                 "MISC": {"short": "Misc", "verbose": "Miscellaneous"}, 
                 "RELIGION": {"short": "Relig", "verbose": "Religion"}, 
                 "ORGANIZATION": {"short": "Org", "verbose":"Organization"}, 
                 "LOCATION": {"short": "Loc", "verbose": "Location"},
                 "DURATION": {"short": "Dur", "verbose": "Duration"},
                 "COUNTRY": {"short": "Cntr", "verbose": "Country"},
                 "NATIONALITY": {"short": "Nation", "verbose": "Nationality"},
                 "CAUSE_OF_DEATH": {"short": "CoD", "verbose": "Cause of Death"},
                 "IDEOLOGY": {"short": "Ideo", "verbose": "Ideology"},
                 "URL": {"short": "url", "verbose": "URL"},
                 "STATE_OR_PROVINCE": {"short": "SoP", "verbose": "State or Province"},
                 "NUMBER": {"short": "Num", "verbose": "Number"},
                 "CRIMINAL_CHARGE": {"short": "Crim", "verbose": "Criminal Charge"},
                 "TITLE": {"short": "Tit", "verbose": "Title"},
                 "PERSON": {"short": "Per", "verbose": "Person"},
                 "DATE": {"short": "Dat", "verbose": "Date"},
                 "CITY": {"short": "Cit", "verbose": "City"}
             }
         }

# %%
relations={
             "relations": {
                 "org:city_of_headquarters": {"short": "City of Headquarters", "verbose": "City of Headquarters", "symmetric": false}, 
                 "per:spouse": {"short": "Spouse", "verbose": "Spouse", "symmetric": false}, 
                 "per:cities_of_residence": {"short": "Cities of Residence", "verbose": "Cities of Residence", "symmetric": false}, 
                 "per:city_of_death": {"short": "City of Death", "verbose": "City of Death", "symmetric": false}, 
                 "org:country_of_headquarters": {"short": "Country of Headquarters", "verbose": "Country of Headquarters", "symmetric": false}, 
                 "per:country_of_birth": {"short": "Country of Birth", "verbose": "Country of Birth", "symmetric": false}, 
                 "per:siblings": {"short": "Siblings", "verbose": "Siblings", "symmetric": false}, 
                 "org:shareholders": {"short": "Shareholders", "verbose": "Shareholders", "symmetric": false}, 
                 "org:member_of": {"short": "Member of", "verbose": "Member of", "symmetric": false}, 
                 "org:dissolved": {"short": "Dissolved", "verbose": "Dissolved", "symmetric": false}, 
                 "per:schools_attended": {"short": "Schools Attended", "verbose": "Schools Attended", "symmetric": false}, 
                 "org:political/religious_affiliation": {"short": "Political/Religious affiliation", "verbose": "Political/Religious affiliation", "symmetric": false}, 
                 "per:city_of_birth": {"short": "City of Birth", "verbose": "City of Birth", "symmetric": false}, 
                 "per:children": {"short": "Children", "verbose": "Children", "symmetric": false}, 
                 "org:top_members/employees": {"short": "Top Members / Employees", "verbose": "Top Members / Employees", "symmetric": false}, 
                 "per:stateorprovince_of_birth": {"short": "State or Province of Birth", "verbose": "State or Province of Birth", "symmetric": false}, 
                 "per:stateorprovince_of_death": {"short": "State or Province of Death", "verbose": "State or Province of Death", "symmetric": false}, 
                 "org:number_of_employees/members": {"short": "Number of Employees/Members", "verbose": "Number of Employees/Members", "symmetric": false}, 
                 "per:countries_of_residence": {"short": "Countries of Residence", "verbose": "Countries of Residence", "symmetric": false}, 
                 "org:founded": {"short": "Founded", "verbose": "Founded", "symmetric": false}, 
                 "per:country_of_death": {"short": "Country of Death", "verbose": "Country of Death", "symmetric": false}, 
                 "per:title": {"short": "Title", "verbose": "Title", "symmetric": false}, 
                 "org:stateorprovince_of_headquarters": {"short": "State or Province of Headquarters", "verbose": "State or Province of Headquarters", "symmetric": false}, 
                 "per:religion": {"short": "Religion", "verbose": "Religion", "symmetric": false}, 
                 "org:founded_by": {"short": "Founded by", "verbose": "Founded by", "symmetric": false}, 
                 "per:age": {"short": "Age", "verbose": "Age", "symmetric": false}, 
                 "no_relation": {"short": "No Relation", "verbose": "No Relation", "symmetric": false}, 
                 "per:stateorprovinces_of_residence": {"short": "State or Provinces of Residence", "verbose": "State or Provinces of Residence", "symmetric": false}, 
                 "org:website": {"short": "Website", "verbose": "Website", "symmetric": false}, 
                 "per:employee_of": {"short": "Employee Of", "verbose": "Employee Of", "symmetric": false}, 
                 "org:parents": {"short": "Organization Parents", "verbose": "Organization Parents", "symmetric": false}, 
                 "per:parents": {"short": "Person Parents", "verbose": "Person Parents", "symmetric": false}, 
                 "org:alternate_names": {"short": "Organization Alternate Names", "verbose": "Organization Alternate Names", "symmetric": false}, 
                 "org:subsidiaries": {"short": "Subsidiaries", "verbose": "Subsidiaries", "symmetric": false}, 
                 "per:alternate_names": {"short": "Person Alternate Names", "verbose": "Person Alternate Names", "symmetric": false}, 
                 "per:cause_of_death": {"short": "Cause of Death", "verbose": "Cause of Death", "symmetric": false}, 
                 "per:date_of_death": {"short": "Date of Death", "verbose": "Date of Death", "symmetric": false}, 
                 "org:members": {"short": "Members", "verbose": "Members", "symmetric": false}, 
                 "per:date_of_birth": {"short": "Date of Birth", "verbose": "Date of Birth", "symmetric": false}, 
                 "per:charges": {"short": "Charges", "verbose": "Charges", "symmetric": false}, 
                 "per:origin": {"short": "Origin", "verbose": "Origin", "symmetric": false}, 
                 "per:other_family": {"short": "Other Family", "verbose": "Other Family", "symmetric": false}
             }
         }
